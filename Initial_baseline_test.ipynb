# %% [markdown]
# # Heterogenous User Preference Prediction

# %%
# %%capture
from tqdm import tqdm_notebook as tqdm
tqdm().pandas()

# %%
import os
from collections import Counter,defaultdict
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
import re
import seaborn as sns
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import classification_report, f1_score
from sklearn.model_selection import StratifiedKFold
from htmldate import find_date
import swifter
from sklearn import metrics
import seaborn as sns
from sklearn.linear_model import LogisticRegressionCV
from sklearn.preprocessing import scale
import joblib

# %%
SMALL_SIZE = 12
MEDIUM_SIZE = 14
BIGGER_SIZE = 16

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/karthik/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# Filtering Clusters:
# * remove clusters with same centers
# * remove clusters with too few documents and too large documents
# * remove pure clusters
#     * have only conservative or only liberal documents

# %%
# do this after asking professor
# df["dates"] = df["url"].swifter.apply(lambda x: find_date(x))

# %%
# df.to_csv("/data/3/karthik/preference_prediction/articles_with_dates.csv",index=False)

# %% [markdown]
# ## 1. General Functions

# %%
from functools import wraps
from time import time

def timing(f):
    @wraps(f)
    def wrap(*args, **kw):
        ts = time()
        result = f(*args, **kw)
        te = time()
        print('\n***** func:%r took: %2.4f sec ******' % \
          (f.__name__, te-ts))
        return result
    return wrap

# %%
def preprocess_text(text):
    """
    """
    pass

def sample_documents(df):
    """
    """
    df_sample = df.sample(frac=0.2, replace=False, random_state=48)
    boolean = not df["article_id"].is_unique
    print("Duplicate values : %s" %str(boolean))
    return df_sample

def tokenize_sentences(text):
    """
    """
    first_10 = sent_tokenize(text)[:10]
    return first_10

@timing
def load_data(path):
    """
    """
    df = pd.read_csv(path)
    print(df.columns)
    print("Df original shape : %s" %str(df.shape))
    # drop rows with text as nan
    df = df[df['text'].notna()]
    print("Df shape after dropping nan text : %s" %str(df.shape))
    # drop articles that have stance = 0
    df = df[df["source_partisan_score"] != 0]
    print("Df shape after dropping 0 stance articles : %s" %str(df.shape))
    # convert articles of stance -1,+1,-2,+2
    df["binary_ps"] = df["source_partisan_score"].apply(lambda x: 1 if x>=1 else 0)
    
    return df

@timing
def vectorize(texts):
    """
    """
    tfidf_vectorizer = TfidfVectorizer(min_df=30, binary=False, max_df=.7, stop_words='english')
    vectors = tfidf_vectorizer.fit_transform(texts)
    vocab = tfidf_vectorizer.vocabulary_
    print("vocab_size : %s"%str(len(vocab)))
    return vectors,vocab

@timing
def cluster_documents(text_vectors,random_state=24,n_clusters=1000):
    """
    """
    km = MiniBatchKMeans(n_clusters=n_clusters, random_state=random_state, n_init=1, max_iter=100, batch_size=1000)
    clusters = km.fit_predict(text_vectors)
    return clusters,km

@timing
def get_cluster_sizes(clusters):
    """
    """
    cluster_sizes = Counter(clusters.labels_)
    return cluster_sizes

def plot_size_dist(cluster_sizes):
    """
    """
    plt.figure(figsize=(20,10))
    plt.bar(cluster_sizes.keys(), cluster_sizes.values(),width=2)
    plt.xlim([0,1000])
    plt.xlabel("Cluster-Number")
    plt.ylim([0,4000])
    plt.ylabel("Documents in Cluster")
    plt.show()


@timing
def run_clustering(path="/data/3/karthik/preference_prediction/articles.csv"):
    """
    """
    df = load_data(path)
    
    df_sample = sample_documents(df)
    
    print("Sampling size : %s" %str(df_sample.shape))
    
    print("Selecting first 10 sentences")
    df_sample["first_10"] = df_sample["text"].apply(lambda x: " ".join(sent_tokenize(x)))
    
    print("Adding title and first 10 sentences")
    df_sample["title_first_10"] = df_sample["title"] + ". " + df_sample["first_10"]
    
    print("Vectorizing text")
    X,vocab = vectorize(df_sample["title_first_10"])
    print("Clustering documents")
    clusters,km = cluster_documents(X)
    
    cluster_sizes = get_cluster_sizes(km)
    
    sil_score = metrics.silhouette_score(X, km.labels_, metric='euclidean')
    
    return df_sample,cluster_sizes,clusters,sil_score,vocab,km,X

@timing
def convert_matrix_tuple_list(matrix_2d):
    """
    """
    bookkeeper = defaultdict(int)
    tup_list = []
    for i in range(matrix_2d.shape[0]):
        for j in range(matrix_2d.shape[1]):
            if i != j and bookkeeper[(i,j)]==0 and bookkeeper[(j,i)]==0:
                tup_list.append((i,j,matrix_2d[i,j]))
                bookkeeper[(i,j)] = 1
                bookkeeper[(j,i)] = 1
    return tup_list

@timing
def filter_clusters(cluster_centers,cluster_sizes,min_filter=30,max_filter=1000):
    """
    """
    clusters_2_filter = []
    for i in range(cluster_centers.shape[0]):
        if cluster_sizes[i]<=min_filter or cluster_sizes[i]>=max_filter:
            clusters_2_filter.append(i)
    
    return clusters_2_filter
    

@timing
def create_cluster_pairwise_selection_results(pairwise_results,cluster_sizes):
    """
    """
    df = pd.DataFrame(pairwise_results,columns=["Cluster 1","Cluster 2","Cosine Distance"])
    df["Cluster 1 Size"] = df["Cluster 1"].apply(lambda x:cluster_sizes[x])
    df["Cluster 2 Size"] = df["Cluster 2"].apply(lambda x:cluster_sizes[x])
    return df

@timing
def cluster2doc(texts,cluster_labels):
    """
    """
    cluster_2_doc = defaultdict(list)
    for index,text in enumerate(texts):
        cluster = cluster_labels[index]
        cluster_2_doc[cluster].append(index)
    return cluster_2_doc


def check_cluster_purity(cluster_id,cluster_2_doc_map,df):
    """
    """
    ps_scores = []
    for doc_index in cluster_2_doc_map[cluster_id]:
        ps_scores.append( df["binary_ps"].iloc[doc_index])
    
    unique,count = np.unique(ps_scores, return_counts=True)
    
    if len(unique)==1:
        return True
    else :
        if count[0] >= purity and count[1] >= purity:
            
            return False
        else:
            return True

@timing
def remove_pure_clusters(cluster_pairs,cluster_2_doc_map,df,purity=100):
    """
    """
    filtered_pairs = []
    for cp in cluster_pairs:
        ps_scores_1 = []
        ps_scores_2 = []
        for doc_index in cluster_2_doc_map[cp[0]]:
            ps_scores_1.append( df["binary_ps"].iloc[doc_index])
        for doc_index in cluster_2_doc_map[cp[1]]:
            ps_scores_2.append( df["binary_ps"].iloc[doc_index])
        
        if len(set(ps_scores_1)) == 1:
            pass
        elif len(set(ps_scores_2))==1:
            pass
        elif len(set(ps_scores_1))==1 and len(set(ps_scores_2))==1:
            pass
        else:
            c1c = Counter(ps_scores_1)
            c2c = Counter(ps_scores_2)
            if c1c[0] >= purity and c1c[1] >= purity and c2c[0] >= purity and c2c[1] >= purity:
                filtered_pairs.append(cp)
    
    return filtered_pairs
            

def create_train_test(cluster_pair,cluster2doc,X_feats,df,user_type="Heterogeneous"):
    """
    Labels are based on conservative when homogenous
    """
    c1 = cluster_pair[0]
    c2 = cluster_pair[1]
    
    x_train = X_feats[cluster2doc[c1]]
    x_test = X_feats[cluster2doc[c2]]
    
    ps_train = df["binary_ps"].values[cluster2doc[c1]]
    ps_test = df["binary_ps"].values[cluster2doc[c2]]
    
    if user_type == "Heterogeneous":
        y_train = ps_train
        y_test = list(map(lambda x: 0.0 if x==1.0 else 1.0,ps_test))
    
    if user_type == "Homogeneous":
        y_train = ps_train
        y_test = ps_test
    
    u_train,c_train = np.unique(y_train, return_counts=True)
    u_test,c_test = np.unique(y_test, return_counts=True)
    print("Train Label Dist :\n %s : %s\n %s:%s" %(str(u_train[0]),str(c_train[0]),str(u_train[1]),str(c_train[1])))
    print("Test Label Dist :\n %s : %s\n %s:%s" %(str(u_test[0]),str(c_test[0]),str(u_test[1]),str(c_test[1])))
    
    assert x_train.shape[0] == len(y_train)
    assert x_test.shape[0] == len(y_test)
    
    return x_train,x_test,y_train,y_test

@timing
def run_cluster_filtering(km,cluster_sizes,min_filter,max_filter,cluster_2_doc_map,dist_threshold=0.2):
    """
    """
    cluster_centers = km.cluster_centers_
    pairwise_dist = cosine_similarity(cluster_centers)
    pairwise_scores_list = convert_matrix_tuple_list(pairwise_dist)
    print("Original no of cluster pairs : %s" %str(len(pairwise_scores_list)))
    
    # filter out clusters with same centers
    filtered_pairwise_scores = list(filter(lambda x: x[2]>0 , pairwise_scores_list))
    print("no of clusters after filtering out clusters with same centers : %s" %str(len(filtered_pairwise_scores)))
    
    # filter out extremely small clusters and large clusters
    clusters_2_remove = filter_clusters(cluster_centers,cluster_sizes,min_filter=500,max_filter=3000)
    filtered_pairwise_scores = list(filter(lambda x: x[0] not in clusters_2_remove and x[1] not in clusters_2_remove,filtered_pairwise_scores))
    print("no of clusters after filtering out too small and too large clusters : %s" %str(len(filtered_pairwise_scores)))

    # remove pure clusters, checks if either of the clusters in a pair are pure
    filtered_pairwise_scores = remove_pure_clusters(filtered_pairwise_scores,cluster_2_doc_map,df,purity=100)
    print("no of clusters after filtering out pure clusters : %s" %str(len(filtered_pairwise_scores)))
    
    # remove clusters that are too similar i.e cosine sim < 0.1 (centers are almost the same)
#     filtered_pairwise_scores = list(filter(lambda x: x[2]>dist_threshold , filtered_pairwise_scores))
#     print("no of clusters after filtering out too similar clusters : %s" %str(len(filtered_pairwise_scores)))
    
    print(np.mean(filtered_pairwise_scores))
    
    top_100_filtered = sorted(filtered_pairwise_scores,key=lambda x:x[2],reverse=True)[:100]
    
    pairwise_results = create_cluster_pairwise_selection_results(top_100_filtered,cluster_sizes)
    
    return pairwise_results
    

def get_scores(y_test,predictions,threshold):
    """
    """
    predicted_probas = predictions[:,1]
    predictions = np.where(predicted_probas>=threshold,1,0).flatten()
    f1 = metrics.f1_score(y_test,predictions,zero_division=0)
    precision = metrics.precision_score(y_test,predictions,zero_division=0)
    recall = metrics.recall_score(y_test,predictions,zero_division=0)
    accuracy = metrics.accuracy_score(y_test,predictions)
    
    return f1,precision,recall,accuracy
    
def run_model(x_train,x_test,y_train,y_test):
    """
    """
    clf = LogisticRegressionCV(cv=5,random_state=0,max_iter=1000,n_jobs=-1).fit(x_train, y_train)
    predicted_probas = clf.predict_proba(x_test)
    print(predicted_probas.shape)
    return clf,predicted_probas

@timing
def plot_sim_vs_score(df_results,threshold):
    """
    """
    fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(15,15))
    axes = ax.ravel()
    sim_score = df_results["Cosine Distance"].tolist()
    scores = df_results["threshold - %s"%str(threshold)].tolist()
    f1,precision,recall,accuracy = zip(*scores)
    
    s = 50
    
    axes[0].scatter(sim_score,f1,marker="*",s=s)
    z = np.polyfit(sim_score,f1, 1)
    p = np.poly1d(z)
    axes[0].plot(sim_score,p(sim_score),"r--")
    axes[0].set_xlabel("Cosine Similarity between cluster pairs")
    axes[0].set_ylabel("F1-Score")
    
    axes[1].scatter(sim_score,precision,marker="o",s=s)
    z = np.polyfit(sim_score,precision, 1)
    p = np.poly1d(z)
    axes[1].plot(sim_score,p(sim_score),"r--")
    axes[1].set_xlabel("Cosine Similarity between cluster pairs")
    axes[1].set_ylabel("Precision")
    
    axes[2].scatter(sim_score,recall,marker="^",s=s)
    z = np.polyfit(sim_score,recall, 1)
    p = np.poly1d(z)
    axes[2].plot(sim_score,p(sim_score),"r--")
    axes[2].set_xlabel("Cosine Similarity between cluster pairs")
    axes[2].set_ylabel("Recall")
    
    axes[3].scatter(sim_score,accuracy,marker="+",s=s)
    z = np.polyfit(sim_score,accuracy, 1)
    p = np.poly1d(z)
    axes[3].plot(sim_score,p(sim_score),"r--")
    axes[3].set_xlabel("Cosine Similarity between cluster pairs")
    axes[3].set_ylabel("Accuracy")
    
    fig.suptitle("Cluster Similarity vs Classifier Performance | Threshold : %s" %str(threshold))
    fig.tight_layout()
    
    plt.show()

@timing
def run_train_all(X,cluster_2_doc_map,df,pairwise_results,thresholds = [0.5,0.7,0.9],user_type="Heterogeneous"):
    """
    """
    results = defaultdict(list)
    for index,row in pairwise_results.iterrows():
            print("Training model for cluster pair : %s" %str(index))
            x_train,x_test,y_train,y_test = create_train_test(cluster_pair=(row[0],row[1]),
                                                              cluster2doc=cluster_2_doc_map,
                                                              X_feats=X,
                                                              df=df,
                                                              user_type=user_type)

            clf,predicted_probas = run_model(x_train,x_test,y_train,y_test)

            for t in thresholds:
                f1,precision,recall,accuracy = get_scores(y_test,
                                                          predictions=predicted_probas,
                                                          threshold=t)
                results[t].append((f1,precision,recall,accuracy))
    
    return results

# %% [markdown]
# ## 2. Clustering

# %%
df,cluster_sizes,clusters,sil_score,vocab,km,X = run_clustering()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /data/1/karthik/anaconda3/envs/upp/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2156         try:
# -> 2157             data = self._reader.read(nrows)
#    2158         except StopIteration:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /data/1/karthik/anaconda3/envs/upp/lib/python3.8/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     529
# --> 530 def is_categorical_dtype(arr_or_dtype) -> bool:
#     531     """
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-734574bcbc2e> in <module>
# ----> 1 df,cluster_sizes,clusters,sil_score,vocab,km,X = run_clustering()
#
# <ipython-input-7-6d4dab778ea1> in wrap(*args, **kw)
#       6     def wrap(*args, **kw):
#       7         ts = time()
# ----> 8         result = f(*args, **kw)
#       9         te = time()
#      10         print('\n***** func:%r took: %2.4f sec ******' % \
#
# <ipython-input-47-3142bbf11d74> in run_clustering(path)
#      77     """
#      78     """
# ---> 79     df = load_data(path)
#      80
#      81     df_sample = sample_documents(df)
#
# <ipython-input-7-6d4dab778ea1> in wrap(*args, **kw)
#       6     def wrap(*args, **kw):
#       7         ts = time()
# ----> 8         result = f(*args, **kw)
#       9         te = time()
#      10         print('\n***** func:%r took: %2.4f sec ******' % \
#
# <ipython-input-47-3142bbf11d74> in load_data(path)
#      22     """
#      23     """
# ---> 24     df = pd.read_csv(path)
#      25     print(df.columns)
#      26     print("Df original shape : %s" %str(df.shape))
#
# /data/1/karthik/anaconda3/envs/upp/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /data/1/karthik/anaconda3/envs/upp/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# /data/1/karthik/anaconda3/envs/upp/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# /data/1/karthik/anaconda3/envs/upp/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2155     def read(self, nrows=None):
#    2156         try:
# -> 2157             data = self._reader.read(nrows)
#    2158         except StopIteration:
#    2159             if self._first_chunk:
#
# KeyboardInterrupt:

# %%
sil_score

# %%
plot_size_dist(cluster_sizes)

# %% [markdown]
# ## 3. Pairwise Cluster Identification

# %%
cluster_2_doc_map = cluster2doc(texts=df["title_first_10"],cluster_labels=km.labels_)
# Out:
# ***** func:'cluster2doc' took: 0.1880 sec ******

# %%
pairwise_results = run_cluster_filtering(km=km,
                                         cluster_sizes=cluster_sizes,
                                         min_filter=500,
                                         max_filter=3000,
                                         cluster_2_doc_map=cluster_2_doc_map)
# Out:
# ***** func:'convert_matrix_tuple_list' took: 0.8628 sec ******
# Original no of cluster pairs : 499500
# no of clusters after filtering out clusters with same centers : 498077
#
# ***** func:'filter_clusters' took: 0.0030 sec ******
# no of clusters after filtering out too small and too large clusters : 946
#
# ***** func:'remove_pure_clusters' took: 16.6984 sec ******
# no of clusters after filtering out pure clusters : 903
# 238.6926557079935
#
# ***** func:'create_cluster_pairwise_selection_results' took: 0.0028 sec ******
#
# ***** func:'run_cluster_filtering' took: 20.8990 sec ******

# %%
pairwise_results.head(50)
# Out:
#     Cluster 1  Cluster 2  Cosine Distance  Cluster 1 Size  Cluster 2 Size
# 0          87        192         0.927001             763             516
# 1         123        784         0.799419            1565            1757
# 2         123        131         0.787800            1565             701
# 3         131        784         0.761790             701            1757
# 4          78        896         0.759672            1312             537
# 5         125        580         0.721187             727             596
# 6          78        116         0.652988            1312             876
# 7         800        906         0.645706             515             682
# 8         125        987         0.608531             727             749
# 9         443        784         0.603406             871            1757
# 10        123        443         0.591683            1565             871
# 11        136        137         0.572446             934             857
# 12         81        137         0.558594             667             857
# 13        580        987         0.555475             596             749
# 14        144        611         0.547303            1187            2547
# 15        525        611         0.543798             831            2547
# 16        595        784         0.536926             557            1757
# 17         41        137         0.536530            1447             857
# 18        611        784         0.530078            2547            1757
# 19        116        906         0.523462             876             682
# 20        131        443         0.499191             701             871
# 21         41        116         0.474303            1447             876
# 22         78        137         0.466580            1312             857
# 23         87        123         0.456522             763            1565
# 24        270        784         0.453825             615            1757
# 25        121        611         0.452569             942            2547
# 26        116        896         0.448554             876             537
# 27        138        443         0.445808             532             871
# 28        131        595         0.440761             701             557
# 29        203        784         0.436046             620            1757
# 30         78        906         0.434516            1312             682
# 31        611        702         0.428029            2547             682
# 32         87        131         0.421494             763             701
# 33        144        525         0.418858            1187             831
# 34        123        595         0.418683            1565             557
# 35        123        611         0.415207            1565            2547
# 36        611        697         0.414671            2547            1005
# 37        203        270         0.413883             620             615
# 38         87        784         0.409141             763            1757
# 39        443        611         0.407907             871            2547
# 40        138        784         0.407277             532            1757
# 41         84        784         0.405075             639            1757
# 42        137        204         0.403013             857             636
# 43        125        611         0.402585             727            2547
# 44        595        611         0.400837             557            2547
# 45        580        784         0.397152             596            1757
# 46        144        702         0.396030            1187             682
# 47         98        611         0.394326            1723            2547
# 48        123        203         0.389210            1565             620
# 49        131        203         0.387093             701             620

# %% [markdown]
# ## 4. Model Training and Testing

# %%
results = run_train_all(X,cluster_2_doc_map,df,pairwise_results,thresholds = [0.5,0.7,0.9],user_type="Heterogeneous")
# Out:
# Training model for cluster pair : 0
# Train Label Dist :
#  0 : 395
#  1:368
# Test Label Dist :
#  0.0 : 266
#  1.0:250
# (516, 2)
# Training model for cluster pair : 1
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 2
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0.0 : 291
#  1.0:410
# (701, 2)
# Training model for cluster pair : 3
# Train Label Dist :
#  0 : 410
#  1:291
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 4
# Train Label Dist :
#  0 : 684
#  1:628
# Test Label Dist :
#  0.0 : 242
#  1.0:295
# (537, 2)
# Training model for cluster pair : 5
# Train Label Dist :
#  0 : 448
#  1:279
# Test Label Dist :
#  0.0 : 221
#  1.0:375
# (596, 2)
# Training model for cluster pair : 6
# Train Label Dist :
#  0 : 684
#  1:628
# Test Label Dist :
#  0.0 : 387
#  1.0:489
# (876, 2)
# Training model for cluster pair : 7
# Train Label Dist :
#  0 : 368
#  1:147
# Test Label Dist :
#  0.0 : 220
#  1.0:462
# (682, 2)
# Training model for cluster pair : 8
# Train Label Dist :
#  0 : 448
#  1:279
# Test Label Dist :
#  0.0 : 268
#  1.0:481
# (749, 2)
# Training model for cluster pair : 9
# Train Label Dist :
#  0 : 501
#  1:370
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 10
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0.0 : 370
#  1.0:501
# (871, 2)
# Training model for cluster pair : 11
# Train Label Dist :
#  0 : 547
#  1:387
# Test Label Dist :
#  0.0 : 249
#  1.0:608
# (857, 2)
# Training model for cluster pair : 12
# Train Label Dist :
#  0 : 480
#  1:187
# Test Label Dist :
#  0.0 : 249
#  1.0:608
# (857, 2)
# Training model for cluster pair : 13
# Train Label Dist :
#  0 : 375
#  1:221
# Test Label Dist :
#  0.0 : 268
#  1.0:481
# (749, 2)
# Training model for cluster pair : 14
# Train Label Dist :
#  0 : 713
#  1:474
# Test Label Dist :
#  0.0 : 604
#  1.0:1943
# (2547, 2)
# Training model for cluster pair : 15
# Train Label Dist :
#  0 : 191
#  1:640
# Test Label Dist :
#  0.0 : 604
#  1.0:1943
# (2547, 2)
# Training model for cluster pair : 16
# Train Label Dist :
#  0 : 366
#  1:191
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 17
# Train Label Dist :
#  0 : 607
#  1:840
# Test Label Dist :
#  0.0 : 249
#  1.0:608
# (857, 2)
# Training model for cluster pair : 18
# Train Label Dist :
#  0 : 1943
#  1:604
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 19
# Train Label Dist :
#  0 : 489
#  1:387
# Test Label Dist :
#  0.0 : 220
#  1.0:462
# (682, 2)
# Training model for cluster pair : 20
# Train Label Dist :
#  0 : 410
#  1:291
# Test Label Dist :
#  0.0 : 370
#  1.0:501
# (871, 2)
# Training model for cluster pair : 21
# Train Label Dist :
#  0 : 607
#  1:840
# Test Label Dist :
#  0.0 : 387
#  1.0:489
# (876, 2)
# Training model for cluster pair : 22
# Train Label Dist :
#  0 : 684
#  1:628
# Test Label Dist :
#  0.0 : 249
#  1.0:608
# (857, 2)
# Training model for cluster pair : 23
# Train Label Dist :
#  0 : 395
#  1:368
# Test Label Dist :
#  0.0 : 597
#  1.0:968
# (1565, 2)
# Training model for cluster pair : 24
# Train Label Dist :
#  0 : 424
#  1:191
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 25
# Train Label Dist :
#  0 : 641
#  1:301
# Test Label Dist :
#  0.0 : 604
#  1.0:1943
# (2547, 2)
# Training model for cluster pair : 26
# Train Label Dist :
#  0 : 489
#  1:387
# Test Label Dist :
#  0.0 : 242
#  1.0:295
# (537, 2)
# Training model for cluster pair : 27
# Train Label Dist :
#  0 : 401
#  1:131
# Test Label Dist :
#  0.0 : 370
#  1.0:501
# (871, 2)
# Training model for cluster pair : 28
# Train Label Dist :
#  0 : 410
#  1:291
# Test Label Dist :
#  0.0 : 191
#  1.0:366
# (557, 2)
# Training model for cluster pair : 29
# Train Label Dist :
#  0 : 451
#  1:169
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 30
# Train Label Dist :
#  0 : 684
#  1:628
# Test Label Dist :
#  0.0 : 220
#  1.0:462
# (682, 2)
# Training model for cluster pair : 31
# Train Label Dist :
#  0 : 1943
#  1:604
# Test Label Dist :
#  0.0 : 235
#  1.0:447
# (682, 2)
# Training model for cluster pair : 32
# Train Label Dist :
#  0 : 395
#  1:368
# Test Label Dist :
#  0.0 : 291
#  1.0:410
# (701, 2)
# Training model for cluster pair : 33
# Train Label Dist :
#  0 : 713
#  1:474
# Test Label Dist :
#  0.0 : 640
#  1.0:191
# (831, 2)
# Training model for cluster pair : 34
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0.0 : 191
#  1.0:366
# (557, 2)
# Training model for cluster pair : 35
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0.0 : 604
#  1.0:1943
# (2547, 2)
# Training model for cluster pair : 36
# Train Label Dist :
#  0 : 1943
#  1:604
# Test Label Dist :
#  0.0 : 281
#  1.0:724
# (1005, 2)
# Training model for cluster pair : 37
# Train Label Dist :
#  0 : 451
#  1:169
# Test Label Dist :
#  0.0 : 191
#  1.0:424
# (615, 2)
# Training model for cluster pair : 38
# Train Label Dist :
#  0 : 395
#  1:368
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 39
# Train Label Dist :
#  0 : 501
#  1:370
# Test Label Dist :
#  0.0 : 604
#  1.0:1943
# (2547, 2)
# Training model for cluster pair : 40
# Train Label Dist :
#  0 : 401
#  1:131
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 41
# Train Label Dist :
#  0 : 490
#  1:149
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 42
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0.0 : 246
#  1.0:390
# (636, 2)
# Training model for cluster pair : 43
# Train Label Dist :
#  0 : 448
#  1:279
# Test Label Dist :
#  0.0 : 604
#  1.0:1943
# (2547, 2)
# Training model for cluster pair : 44
# Train Label Dist :
#  0 : 366
#  1:191
# Test Label Dist :
#  0.0 : 604
#  1.0:1943
# (2547, 2)
# Training model for cluster pair : 45
# Train Label Dist :
#  0 : 375
#  1:221
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 46
# Train Label Dist :
#  0 : 713
#  1:474
# Test Label Dist :
#  0.0 : 235
#  1.0:447
# (682, 2)
# Training model for cluster pair : 47
# Train Label Dist :
#  0 : 827
#  1:896
# Test Label Dist :
#  0.0 : 604
#  1.0:1943
# (2547, 2)
# Training model for cluster pair : 48
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0.0 : 169
#  1.0:451
# (620, 2)
# Training model for cluster pair : 49
# Train Label Dist :
#  0 : 410
#  1:291
# Test Label Dist :
#  0.0 : 169
#  1.0:451
# (620, 2)
# Training model for cluster pair : 50
# Train Label Dist :
#  0 : 490
#  1:149
# Test Label Dist :
#  0.0 : 604
#  1.0:1943
# (2547, 2)
# Training model for cluster pair : 51
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0.0 : 604
#  1.0:1943
# (2547, 2)
# Training model for cluster pair : 52
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0.0 : 131
#  1.0:401
# (532, 2)
# Training model for cluster pair : 53
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0.0 : 311
#  1.0:399
# (710, 2)
# Training model for cluster pair : 54
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0.0 : 131
#  1.0:401
# (532, 2)
# Training model for cluster pair : 55
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0.0 : 220
#  1.0:462
# (682, 2)
# Training model for cluster pair : 56
# Train Label Dist :
#  0 : 333
#  1:194
# Test Label Dist :
#  0.0 : 169
#  1.0:451
# (620, 2)
# Training model for cluster pair : 57
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0.0 : 242
#  1.0:295
# (537, 2)
# Training model for cluster pair : 58
# Train Label Dist :
#  0 : 191
#  1:640
# Test Label Dist :
#  0.0 : 235
#  1.0:447
# (682, 2)
# Training model for cluster pair : 59
# Train Label Dist :
#  0 : 489
#  1:387
# Test Label Dist :
#  0.0 : 249
#  1.0:608
# (857, 2)
# Training model for cluster pair : 60
# Train Label Dist :
#  0 : 684
#  1:628
# Test Label Dist :
#  0.0 : 187
#  1.0:480
# (667, 2)
# Training model for cluster pair : 61
# Train Label Dist :
#  0 : 489
#  1:387
# Test Label Dist :
#  0.0 : 147
#  1.0:368
# (515, 2)
# Training model for cluster pair : 62
# Train Label Dist :
#  0 : 250
#  1:266
# Test Label Dist :
#  0.0 : 182
#  1.0:330
# (512, 2)
# Training model for cluster pair : 63
# Train Label Dist :
#  0 : 294
#  1:241
# Test Label Dist :
#  0.0 : 604
#  1.0:1943
# (2547, 2)
# Training model for cluster pair : 64
# Train Label Dist :
#  0 : 375
#  1:221
# Test Label Dist :
#  0.0 : 604
#  1.0:1943
# (2547, 2)
# Training model for cluster pair : 65
# Train Label Dist :
#  0 : 191
#  1:640
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 66
# Train Label Dist :
#  0 : 501
#  1:370
# Test Label Dist :
#  0.0 : 191
#  1.0:366
# (557, 2)
# Training model for cluster pair : 67
# Train Label Dist :
#  0 : 424
#  1:191
# Test Label Dist :
#  0.0 : 604
#  1.0:1943
# (2547, 2)
# Training model for cluster pair : 68
# Train Label Dist :
#  0 : 641
#  1:301
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 69
# Train Label Dist :
#  0 : 395
#  1:368
# Test Label Dist :
#  0.0 : 169
#  1.0:451
# (620, 2)
# Training model for cluster pair : 70
# Train Label Dist :
#  0 : 607
#  1:840
# Test Label Dist :
#  0.0 : 387
#  1.0:547
# (934, 2)
# Training model for cluster pair : 71
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 72
# Train Label Dist :
#  0 : 480
#  1:187
# Test Label Dist :
#  0.0 : 754
#  1.0:1003
# (1757, 2)
# Training model for cluster pair : 73
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0.0 : 483
#  1.0:730
# (1213, 2)
# Training model for cluster pair : 74
# Train Label Dist :
#  0 : 684
#  1:628
# Test Label Dist :
#  0.0 : 483
#  1.0:730
# (1213, 2)
# Training model for cluster pair : 75
# Train Label Dist :
#  0 : 730
#  1:483
# Test Label Dist :
#  0.0 : 220
#  1.0:462
# (682, 2)
# Training model for cluster pair : 76
# Train Label Dist :
#  0 : 399
#  1:311
# Test Label Dist :
#  0.0 : 220
#  1.0:462
# (682, 2)
# Training model for cluster pair : 77
# Train Label Dist :
#  0 : 489
#  1:387
# Test Label Dist :
#  0.0 : 483
#  1.0:730
# (1213, 2)
# Training model for cluster pair : 78
# Train Label Dist :
#  0 : 641
#  1:301
# Test Label Dist :
#  0.0 : 281
#  1.0:724
# (1005, 2)
# Training model for cluster pair : 79
# Train Label Dist :
#  0 : 641
#  1:301
# Test Label Dist :
#  0.0 : 406
#  1.0:598
# (1004, 2)
# Training model for cluster pair : 80
# Train Label Dist :
#  0 : 607
#  1:840
# Test Label Dist :
#  0.0 : 246
#  1.0:390
# (636, 2)
# Training model for cluster pair : 81
# Train Label Dist :
#  0 : 641
#  1:301
# Test Label Dist :
#  0.0 : 474
#  1.0:713
# (1187, 2)
# Training model for cluster pair : 82
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0.0 : 221
#  1.0:375
# (596, 2)
# Training model for cluster pair : 83
# Train Label Dist :
#  0 : 490
#  1:149
# Test Label Dist :
#  0.0 : 597
#  1.0:968
# (1565, 2)
# Training model for cluster pair : 84
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0.0 : 191
#  1.0:424
# (615, 2)
# Training model for cluster pair : 85
# Train Label Dist :
#  0 : 607
#  1:840
# Test Label Dist :
#  0.0 : 628
#  1.0:684
# (1312, 2)
# Training model for cluster pair : 86
# Train Label Dist :
#  0 : 390
#  1:246
# Test Label Dist :
#  0.0 : 220
#  1.0:462
# (682, 2)
# Training model for cluster pair : 87
# Train Label Dist :
#  0 : 490
#  1:149
# Test Label Dist :
#  0.0 : 191
#  1.0:424
# (615, 2)
# Training model for cluster pair : 88
# Train Label Dist :
#  0 : 395
#  1:368
# Test Label Dist :
#  0.0 : 182
#  1.0:330
# (512, 2)
# Training model for cluster pair : 89
# Train Label Dist :
#  0 : 1943
#  1:604
# Test Label Dist :
#  0.0 : 268
#  1.0:481
# (749, 2)
# Training model for cluster pair : 90
# Train Label Dist :
#  0 : 480
#  1:187
# Test Label Dist :
#  0.0 : 295
#  1.0:427
# (722, 2)
# Training model for cluster pair : 91
# Train Label Dist :
#  0 : 641
#  1:301
# Test Label Dist :
#  0.0 : 640
#  1.0:191
# (831, 2)
# Training model for cluster pair : 92
# Train Label Dist :
#  0 : 401
#  1:131
# Test Label Dist :
#  0.0 : 191
#  1.0:424
# (615, 2)
# Training model for cluster pair : 93
# Train Label Dist :
#  0 : 399
#  1:311
# Test Label Dist :
#  0.0 : 246
#  1.0:390
# (636, 2)
# Training model for cluster pair : 94
# Train Label Dist :
#  0 : 401
#  1:131
# Test Label Dist :
#  0.0 : 604
#  1.0:1943
# (2547, 2)
# Training model for cluster pair : 95
# Train Label Dist :
#  0 : 641
#  1:301
# Test Label Dist :
#  0.0 : 249
#  1.0:608
# (857, 2)
# Training model for cluster pair : 96
# Train Label Dist :
#  0 : 827
#  1:896
# Test Label Dist :
#  0.0 : 474
#  1.0:713
# (1187, 2)
# Training model for cluster pair : 97
# Train Label Dist :
#  0 : 401
#  1:131
# Test Label Dist :
#  0.0 : 194
#  1.0:333
# (527, 2)
# Training model for cluster pair : 98
# Train Label Dist :
#  0 : 730
#  1:483
# Test Label Dist :
#  0.0 : 241
#  1.0:294
# (535, 2)
# Training model for cluster pair : 99
# Train Label Dist :
#  0 : 250
#  1:266
# Test Label Dist :
#  0.0 : 169
#  1.0:451
# (620, 2)
#
# ***** func:'run_train_all' took: 503.0624 sec ******

# %%
df_results = pairwise_results.copy()
for k in results:
    df_results["threshold - %s"%str(k)] = results[k]

# %%
joblib.dump(df_results,"Results_df.joblib")
# Out:
# ['Results_df.joblib']

# %% [markdown]
# ## 5. Results and Analysis

# %%
plot_sim_vs_score(df_results,threshold=0.5)
# Out:
# ***** func:'plot_sim_vs_score' took: 0.6006 sec ******

# %%
plot_sim_vs_score(df_results,threshold=0.7)
# Out:
# ***** func:'plot_sim_vs_score' took: 0.6016 sec ******

# %%
plot_sim_vs_score(df_results,threshold=0.9)
# Out:
# ***** func:'plot_sim_vs_score' took: 0.5721 sec ******

# %% [markdown]
# ## Homogeneous User Results

# %%
results_homogeneous = run_train_all(X,cluster_2_doc_map,df,pairwise_results,thresholds = [0.5,0.7,0.9],user_type="Homogeneous")
# Out:
# Training model for cluster pair : 0
# Train Label Dist :
#  0 : 395
#  1:368
# Test Label Dist :
#  0 : 250
#  1:266
# (516, 2)
# Training model for cluster pair : 1
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 2
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0 : 410
#  1:291
# (701, 2)
# Training model for cluster pair : 3
# Train Label Dist :
#  0 : 410
#  1:291
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 4
# Train Label Dist :
#  0 : 684
#  1:628
# Test Label Dist :
#  0 : 295
#  1:242
# (537, 2)
# Training model for cluster pair : 5
# Train Label Dist :
#  0 : 448
#  1:279
# Test Label Dist :
#  0 : 375
#  1:221
# (596, 2)
# Training model for cluster pair : 6
# Train Label Dist :
#  0 : 684
#  1:628
# Test Label Dist :
#  0 : 489
#  1:387
# (876, 2)
# Training model for cluster pair : 7
# Train Label Dist :
#  0 : 368
#  1:147
# Test Label Dist :
#  0 : 462
#  1:220
# (682, 2)
# Training model for cluster pair : 8
# Train Label Dist :
#  0 : 448
#  1:279
# Test Label Dist :
#  0 : 481
#  1:268
# (749, 2)
# Training model for cluster pair : 9
# Train Label Dist :
#  0 : 501
#  1:370
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 10
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0 : 501
#  1:370
# (871, 2)
# Training model for cluster pair : 11
# Train Label Dist :
#  0 : 547
#  1:387
# Test Label Dist :
#  0 : 608
#  1:249
# (857, 2)
# Training model for cluster pair : 12
# Train Label Dist :
#  0 : 480
#  1:187
# Test Label Dist :
#  0 : 608
#  1:249
# (857, 2)
# Training model for cluster pair : 13
# Train Label Dist :
#  0 : 375
#  1:221
# Test Label Dist :
#  0 : 481
#  1:268
# (749, 2)
# Training model for cluster pair : 14
# Train Label Dist :
#  0 : 713
#  1:474
# Test Label Dist :
#  0 : 1943
#  1:604
# (2547, 2)
# Training model for cluster pair : 15
# Train Label Dist :
#  0 : 191
#  1:640
# Test Label Dist :
#  0 : 1943
#  1:604
# (2547, 2)
# Training model for cluster pair : 16
# Train Label Dist :
#  0 : 366
#  1:191
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 17
# Train Label Dist :
#  0 : 607
#  1:840
# Test Label Dist :
#  0 : 608
#  1:249
# (857, 2)
# Training model for cluster pair : 18
# Train Label Dist :
#  0 : 1943
#  1:604
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 19
# Train Label Dist :
#  0 : 489
#  1:387
# Test Label Dist :
#  0 : 462
#  1:220
# (682, 2)
# Training model for cluster pair : 20
# Train Label Dist :
#  0 : 410
#  1:291
# Test Label Dist :
#  0 : 501
#  1:370
# (871, 2)
# Training model for cluster pair : 21
# Train Label Dist :
#  0 : 607
#  1:840
# Test Label Dist :
#  0 : 489
#  1:387
# (876, 2)
# Training model for cluster pair : 22
# Train Label Dist :
#  0 : 684
#  1:628
# Test Label Dist :
#  0 : 608
#  1:249
# (857, 2)
# Training model for cluster pair : 23
# Train Label Dist :
#  0 : 395
#  1:368
# Test Label Dist :
#  0 : 968
#  1:597
# (1565, 2)
# Training model for cluster pair : 24
# Train Label Dist :
#  0 : 424
#  1:191
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 25
# Train Label Dist :
#  0 : 641
#  1:301
# Test Label Dist :
#  0 : 1943
#  1:604
# (2547, 2)
# Training model for cluster pair : 26
# Train Label Dist :
#  0 : 489
#  1:387
# Test Label Dist :
#  0 : 295
#  1:242
# (537, 2)
# Training model for cluster pair : 27
# Train Label Dist :
#  0 : 401
#  1:131
# Test Label Dist :
#  0 : 501
#  1:370
# (871, 2)
# Training model for cluster pair : 28
# Train Label Dist :
#  0 : 410
#  1:291
# Test Label Dist :
#  0 : 366
#  1:191
# (557, 2)
# Training model for cluster pair : 29
# Train Label Dist :
#  0 : 451
#  1:169
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 30
# Train Label Dist :
#  0 : 684
#  1:628
# Test Label Dist :
#  0 : 462
#  1:220
# (682, 2)
# Training model for cluster pair : 31
# Train Label Dist :
#  0 : 1943
#  1:604
# Test Label Dist :
#  0 : 447
#  1:235
# (682, 2)
# Training model for cluster pair : 32
# Train Label Dist :
#  0 : 395
#  1:368
# Test Label Dist :
#  0 : 410
#  1:291
# (701, 2)
# Training model for cluster pair : 33
# Train Label Dist :
#  0 : 713
#  1:474
# Test Label Dist :
#  0 : 191
#  1:640
# (831, 2)
# Training model for cluster pair : 34
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0 : 366
#  1:191
# (557, 2)
# Training model for cluster pair : 35
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0 : 1943
#  1:604
# (2547, 2)
# Training model for cluster pair : 36
# Train Label Dist :
#  0 : 1943
#  1:604
# Test Label Dist :
#  0 : 724
#  1:281
# (1005, 2)
# Training model for cluster pair : 37
# Train Label Dist :
#  0 : 451
#  1:169
# Test Label Dist :
#  0 : 424
#  1:191
# (615, 2)
# Training model for cluster pair : 38
# Train Label Dist :
#  0 : 395
#  1:368
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 39
# Train Label Dist :
#  0 : 501
#  1:370
# Test Label Dist :
#  0 : 1943
#  1:604
# (2547, 2)
# Training model for cluster pair : 40
# Train Label Dist :
#  0 : 401
#  1:131
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 41
# Train Label Dist :
#  0 : 490
#  1:149
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 42
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0 : 390
#  1:246
# (636, 2)
# Training model for cluster pair : 43
# Train Label Dist :
#  0 : 448
#  1:279
# Test Label Dist :
#  0 : 1943
#  1:604
# (2547, 2)
# Training model for cluster pair : 44
# Train Label Dist :
#  0 : 366
#  1:191
# Test Label Dist :
#  0 : 1943
#  1:604
# (2547, 2)
# Training model for cluster pair : 45
# Train Label Dist :
#  0 : 375
#  1:221
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 46
# Train Label Dist :
#  0 : 713
#  1:474
# Test Label Dist :
#  0 : 447
#  1:235
# (682, 2)
# Training model for cluster pair : 47
# Train Label Dist :
#  0 : 827
#  1:896
# Test Label Dist :
#  0 : 1943
#  1:604
# (2547, 2)
# Training model for cluster pair : 48
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0 : 451
#  1:169
# (620, 2)
# Training model for cluster pair : 49
# Train Label Dist :
#  0 : 410
#  1:291
# Test Label Dist :
#  0 : 451
#  1:169
# (620, 2)
# Training model for cluster pair : 50
# Train Label Dist :
#  0 : 490
#  1:149
# Test Label Dist :
#  0 : 1943
#  1:604
# (2547, 2)
# Training model for cluster pair : 51
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0 : 1943
#  1:604
# (2547, 2)
# Training model for cluster pair : 52
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0 : 401
#  1:131
# (532, 2)
# Training model for cluster pair : 53
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0 : 399
#  1:311
# (710, 2)
# Training model for cluster pair : 54
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0 : 401
#  1:131
# (532, 2)
# Training model for cluster pair : 55
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0 : 462
#  1:220
# (682, 2)
# Training model for cluster pair : 56
# Train Label Dist :
#  0 : 333
#  1:194
# Test Label Dist :
#  0 : 451
#  1:169
# (620, 2)
# Training model for cluster pair : 57
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0 : 295
#  1:242
# (537, 2)
# Training model for cluster pair : 58
# Train Label Dist :
#  0 : 191
#  1:640
# Test Label Dist :
#  0 : 447
#  1:235
# (682, 2)
# Training model for cluster pair : 59
# Train Label Dist :
#  0 : 489
#  1:387
# Test Label Dist :
#  0 : 608
#  1:249
# (857, 2)
# Training model for cluster pair : 60
# Train Label Dist :
#  0 : 684
#  1:628
# Test Label Dist :
#  0 : 480
#  1:187
# (667, 2)
# Training model for cluster pair : 61
# Train Label Dist :
#  0 : 489
#  1:387
# Test Label Dist :
#  0 : 368
#  1:147
# (515, 2)
# Training model for cluster pair : 62
# Train Label Dist :
#  0 : 250
#  1:266
# Test Label Dist :
#  0 : 330
#  1:182
# (512, 2)
# Training model for cluster pair : 63
# Train Label Dist :
#  0 : 294
#  1:241
# Test Label Dist :
#  0 : 1943
#  1:604
# (2547, 2)
# Training model for cluster pair : 64
# Train Label Dist :
#  0 : 375
#  1:221
# Test Label Dist :
#  0 : 1943
#  1:604
# (2547, 2)
# Training model for cluster pair : 65
# Train Label Dist :
#  0 : 191
#  1:640
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 66
# Train Label Dist :
#  0 : 501
#  1:370
# Test Label Dist :
#  0 : 366
#  1:191
# (557, 2)
# Training model for cluster pair : 67
# Train Label Dist :
#  0 : 424
#  1:191
# Test Label Dist :
#  0 : 1943
#  1:604
# (2547, 2)
# Training model for cluster pair : 68
# Train Label Dist :
#  0 : 641
#  1:301
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 69
# Train Label Dist :
#  0 : 395
#  1:368
# Test Label Dist :
#  0 : 451
#  1:169
# (620, 2)
# Training model for cluster pair : 70
# Train Label Dist :
#  0 : 607
#  1:840
# Test Label Dist :
#  0 : 547
#  1:387
# (934, 2)
# Training model for cluster pair : 71
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 72
# Train Label Dist :
#  0 : 480
#  1:187
# Test Label Dist :
#  0 : 1003
#  1:754
# (1757, 2)
# Training model for cluster pair : 73
# Train Label Dist :
#  0 : 608
#  1:249
# Test Label Dist :
#  0 : 730
#  1:483
# (1213, 2)
# Training model for cluster pair : 74
# Train Label Dist :
#  0 : 684
#  1:628
# Test Label Dist :
#  0 : 730
#  1:483
# (1213, 2)
# Training model for cluster pair : 75
# Train Label Dist :
#  0 : 730
#  1:483
# Test Label Dist :
#  0 : 462
#  1:220
# (682, 2)
# Training model for cluster pair : 76
# Train Label Dist :
#  0 : 399
#  1:311
# Test Label Dist :
#  0 : 462
#  1:220
# (682, 2)
# Training model for cluster pair : 77
# Train Label Dist :
#  0 : 489
#  1:387
# Test Label Dist :
#  0 : 730
#  1:483
# (1213, 2)
# Training model for cluster pair : 78
# Train Label Dist :
#  0 : 641
#  1:301
# Test Label Dist :
#  0 : 724
#  1:281
# (1005, 2)
# Training model for cluster pair : 79
# Train Label Dist :
#  0 : 641
#  1:301
# Test Label Dist :
#  0 : 598
#  1:406
# (1004, 2)
# Training model for cluster pair : 80
# Train Label Dist :
#  0 : 607
#  1:840
# Test Label Dist :
#  0 : 390
#  1:246
# (636, 2)
# Training model for cluster pair : 81
# Train Label Dist :
#  0 : 641
#  1:301
# Test Label Dist :
#  0 : 713
#  1:474
# (1187, 2)
# Training model for cluster pair : 82
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0 : 375
#  1:221
# (596, 2)
# Training model for cluster pair : 83
# Train Label Dist :
#  0 : 490
#  1:149
# Test Label Dist :
#  0 : 968
#  1:597
# (1565, 2)
# Training model for cluster pair : 84
# Train Label Dist :
#  0 : 968
#  1:597
# Test Label Dist :
#  0 : 424
#  1:191
# (615, 2)
# Training model for cluster pair : 85
# Train Label Dist :
#  0 : 607
#  1:840
# Test Label Dist :
#  0 : 684
#  1:628
# (1312, 2)
# Training model for cluster pair : 86
# Train Label Dist :
#  0 : 390
#  1:246
# Test Label Dist :
#  0 : 462
#  1:220
# (682, 2)
# Training model for cluster pair : 87
# Train Label Dist :
#  0 : 490
#  1:149
# Test Label Dist :
#  0 : 424
#  1:191
# (615, 2)
# Training model for cluster pair : 88
# Train Label Dist :
#  0 : 395
#  1:368
# Test Label Dist :
#  0 : 330
#  1:182
# (512, 2)
# Training model for cluster pair : 89
# Train Label Dist :
#  0 : 1943
#  1:604
# Test Label Dist :
#  0 : 481
#  1:268
# (749, 2)
# Training model for cluster pair : 90
# Train Label Dist :
#  0 : 480
#  1:187
# Test Label Dist :
#  0 : 427
#  1:295
# (722, 2)
# Training model for cluster pair : 91
# Train Label Dist :
#  0 : 641
#  1:301
# Test Label Dist :
#  0 : 191
#  1:640
# (831, 2)
# Training model for cluster pair : 92
# Train Label Dist :
#  0 : 401
#  1:131
# Test Label Dist :
#  0 : 424
#  1:191
# (615, 2)
# Training model for cluster pair : 93
# Train Label Dist :
#  0 : 399
#  1:311
# Test Label Dist :
#  0 : 390
#  1:246
# (636, 2)
# Training model for cluster pair : 94
# Train Label Dist :
#  0 : 401
#  1:131
# Test Label Dist :
#  0 : 1943
#  1:604
# (2547, 2)
# Training model for cluster pair : 95
# Train Label Dist :
#  0 : 641
#  1:301
# Test Label Dist :
#  0 : 608
#  1:249
# (857, 2)
# Training model for cluster pair : 96
# Train Label Dist :
#  0 : 827
#  1:896
# Test Label Dist :
#  0 : 713
#  1:474
# (1187, 2)
# Training model for cluster pair : 97
# Train Label Dist :
#  0 : 401
#  1:131
# Test Label Dist :
#  0 : 333
#  1:194
# (527, 2)
# Training model for cluster pair : 98
# Train Label Dist :
#  0 : 730
#  1:483
# Test Label Dist :
#  0 : 294
#  1:241
# (535, 2)
# Training model for cluster pair : 99
# Train Label Dist :
#  0 : 250
#  1:266
# Test Label Dist :
#  0 : 451
#  1:169
# (620, 2)
#
# ***** func:'run_train_all' took: 501.3876 sec ******

# %%
df_results = pairwise_results.copy()
for k in results_homogeneous:
    df_results["threshold - %s"%str(k)] = results_homogeneous[k]

# %%
joblib.dump(df_results,"Results_df_homogeneous.joblib")
# Out:
# ['Results_df_homogeneous.joblib']

# %%
plot_sim_vs_score(df_results,threshold=0.5)
# Out:
# ***** func:'plot_sim_vs_score' took: 0.6006 sec ******

# %%
plot_sim_vs_score(df_results,threshold=0.7)
# Out:
# ***** func:'plot_sim_vs_score' took: 0.5977 sec ******

# %%
plot_sim_vs_score(df_results,threshold=0.9)
# Out:
# ***** func:'plot_sim_vs_score' took: 0.5943 sec ******
