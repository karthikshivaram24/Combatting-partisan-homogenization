# %% [markdown]
# # Combatting Partisan Homogenization in New Content Recommenders - Baselines(BERT)

# %%
# to do
# test with our prototypes and our actual topic labelled data
# use immigration and guns topic, prototypes have to have differing stance variation

# %% [markdown]
# ## Table of Contents
# ### [Clustering Documents, Filtering and Vectorization](#Clustering_Documents_Filtering_Vectorization)
# ### [Baseline 1 - (Cluster Similarity vs Model Performance)](#Cluster_Similarity_vs_Model_Performance)
# ### [Baseline 2 - (Online Setting Performance)](#Online_Setting_Performance)
# ### [Baseline 3 - (Single Cluster Online Setting Performance)](#Single_Cluster_Online_Setting_Performance)
# ### [Baseline 4 - (Regularization vs Online Setting Performance)](#Regularization_vs_Online_Setting_Performance)
# ### [Baseline 5 - (Learning Rate vs Online Setting Performance)](#Learning_Rate_vs_Online_Setting_Performance)
# ### [Baseline 6 - (Online Setting Mixed Data Performance)](#Online_Setting_Mixed_Data_Performance)
# ### [Baseline 7 - (Learning Rate vs Online Setting Mixed Data Performance)](#Learning_Rate_vs_Online_Setting_Mixed_Data_Performance)

# %% [markdown]
# #### Important:
# * Heterogenous User:
#     * Conservative on Cluster 1 but Liberal on Cluster 2
# * Homogeneous User:
#     * Conservative on Cluster 1 and Cluster 2

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt

# %%
from general_utils import timer

from config import RANDOM_SEED

from bert_utils import load_bert_output

from preprocess_utils import preprocess_texts, tfidf_vectorization, dimensionality_reduction

from clustering_utils import run_clustering, get_cluster_sizes, score_cluster, get_cluster_pairs, get_pairwise_dist, cluster2doc, filter_clusters, get_top_100_clusterpairs

from data_utils import load_data, sample_data, balanced_sampling, create_train_test

from metrics_utils import calculate_avg_precision, calculate_map, get_scores, get_scores_wot, calculate_avg_precision_param_variation, calculate_map_param_variation

from model_utils import ( run_model, 
                         run_bs1_train_all, 
                         run_online_setting_active, 
                         run_bs2_train_all, 
                         run_bs3_train_all, 
                         run_bs4_train_all, 
                         run_bs5_train_all, 
                         run_bs6_train_all, 
                         run_bs7_train_all)

from plotters_baseline import ( plot_size_dist, 
                               bsl1_sim_vs_score_all_users, 
                               regularization_plot_helper, 
                               plot_regularization_vs_metrics_at_k, 
                               combine_scores_reg_vs_metrics_at_k, 
                               plot_regularization_vs_metrics_at_k_cumu, 
                               plot_lr_vs_metrics_at_k, 
                               plot_lr_vs_metrics_at_k_cumu, 
                               plot_online_setting_per_clusterpair, 
                               plot_helper_all_cp, 
                               plot_all_cp_online, 
                               plot_all_cp_singlecluster, 
                               plot_helper_scp, 
                               plot_single_cluster_performance, 
                               plot_mixed_data_all_cp_perf, 
                               plot_helper_md, 
                               plot_prec_sep, 
                               plot_mixed_data_performance_per_cluster, 
                               plot_mixed_data_performance, 
                               combine_scores_cumu_online_setting,
                               plot_mixed_cluster_cumulative, 
                               plot_online_learning_cumulative, 
                               plot_single_cluster_cumulative, 
                               plot_mixed_data_all_cp_perf, 
                               lr_mixed_plot_helper, 
                               plot_lr_vs_metrics_at_k_mixed, 
                               plot_mixed_data_all_cp_precis_lr, 
                               plot_mixed_cluster_cumulative_per_cluster  )
# Out:
# ....... Initializing Settings .....
# Random_Seed Chosen : 15112

# %%
warnings.filterwarnings('ignore')

# %%
SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rcParams['axes.grid'] = True

# %% [markdown]
# # Main Components
#
# 1) Data Loading
# 2) Sampling
# 3) Text Preprocessing
# 4) Vectorization
# 5) Dimensionality Reductions
# 6) Clustering
# 7) Clustering Performance Check
# 8) Cluster Filtering
# 9) Pairwise Selection
# 10) Model Training and Performance
# 11) Pairwise score analysis

# %% [markdown]
# ## Clustering Documents, Filtering and Vectorization <a class="anchor" id="Clustering_Documents_Filtering_Vectorization"></a>

# %%
path = "../articles.csv"

main_df = load_data(path)

sampled_df = sample_data(df=main_df,sample_size=100000,seed=RANDOM_SEED)
print("Sampled Size: %s" %str(sampled_df.shape[0]))

sampled_df["processed_text"] = preprocess_texts(text_lists=sampled_df["text"])

reduced_vectors =  load_bert_output(folder1="/media/karthikshivaram/Extra_disk_1/Bert_model_outputs",
                              folder2="/media/karthikshivaram/Extra_Disk_2/Bert_model_outputs",
                              layer=2,aggregation="mean + max")

print("Bert Embedding Output Shape : %s" %str(reduced_vectors.shape))

clusters,cluster_clf = run_clustering(vectors=reduced_vectors,seed=RANDOM_SEED,num_clusters=1000,clus_type="kmeans")

cluster_sizes = get_cluster_sizes(cluster_clf)

plot_size_dist(cluster_sizes)

cluster_pair_dist_mat = get_pairwise_dist(cluster_clf,dist_type="cosine")

cluster_pairs = get_cluster_pairs(num_clusters=1000)
print(len(cluster_pairs))
# Out:
# Index(['article_id', 'url', 'title', 'text', 'source', 'source_partisan_score',
#        'tweet_id', 'tweet_screen_name', 'tweet_created_at', 'tweet_text'],
#       dtype='object')
# Df original shape : (921037, 10)
# Df shape after dropping nan text : (919430, 10)
# Df shape after dropping duplicate articles based on title : (912084, 10)
# Df shape after dropping 0 stance articles : (630425, 10)
#
# Finished running 'load_data' in 0.4463 mins
#
#
# Finished running 'sample_data' in 0.0018 mins
#
# Sampled Size: 100000
# Running : select_first10
# Running : to_lower
# Running : remove_punc
# Running : remove_small_words
# Running : remove_spaces
#
# Finished running 'preprocess_texts' in 0.3326 mins
#
# First Ten Files : ['/media/karthikshivaram/Extra_disk_1/Bert_model_outputs/0.npy', '/media/karthikshivaram/Extra_disk_1/Bert_model_outputs/1.npy', '/media/karthikshivaram/Extra_disk_1/Bert_model_outputs/2.npy', '/media/karthikshivaram/Extra_disk_1/Bert_model_outputs/3.npy', '/media/karthikshivaram/Extra_disk_1/Bert_model_outputs/4.npy', '/media/karthikshivaram/Extra_disk_1/Bert_model_outputs/5.npy', '/media/karthikshivaram/Extra_disk_1/Bert_model_outputs/6.npy', '/media/karthikshivaram/Extra_disk_1/Bert_model_outputs/7.npy', '/media/karthikshivaram/Extra_disk_1/Bert_model_outputs/8.npy', '/media/karthikshivaram/Extra_disk_1/Bert_model_outputs/9.npy']
# Processing Batch No : 200
# Processing Batch No : 300
# Processing Batch No : 400
# Processing Batch No : 500
# Processing Batch No : 600
# Processing Batch No : 700
# Processing Batch No : 800
# Processing Batch No : 900
# Processing Batch No : 1000
# Processing Batch No : 1100
# Processing Batch No : 1200
# Processing Batch No : 1300
# Processing Batch No : 1400
# Processing Batch No : 1500
# Processing Batch No : 1600
# Processing Batch No : 1700
# Processing Batch No : 1800
# Processing Batch No : 1900
#
# Finished running 'load_bert_output' in 59.8339 mins
#
# Bert Embedding Output Shape : (100000, 1536)
#
# Running KMEANS Clustering with k=1000
#
# Finished running 'run_clustering' in 0.7304 mins
#
#
# Finished running 'get_cluster_sizes' in 0.0003 mins
# Finished running 'get_pairwise_dist' in 0.0002 mins
#
#
# Number of Cluster Pairs : 499500
#
# Finished running 'get_cluster_pairs' in 0.0024 mins
#
# 499500

# %%
doc_2_cluster_map = cluster2doc(num_texts=sampled_df.shape[0],cluster_labels=cluster_clf.labels_)
# Out:
# Finished running 'cluster2doc' in 0.0004 mins

# %%
filtered_cluster_pairs = filter_clusters(cluster_pairs=cluster_pairs,
                                        doc_2_cluster_map=doc_2_cluster_map,
                                        cluster_sizes=cluster_sizes,
                                        partisan_scores=sampled_df["binary_ps"].tolist(),
                                        min_size=450,
                                        max_size=5000,
                                        min_partisan_size=0.4)

print("Filtered CLustered Pairs : %s" %str(len(filtered_cluster_pairs)))
# Out:
# Finished running 'filter_clusters' in 0.1015 mins
#
# Filtered CLustered Pairs : 820

# %%
top100 = get_top_100_clusterpairs(cluster_pairs=filtered_cluster_pairs,dist_matrix=cluster_pair_dist_mat,reverse=True)
# Out:
# Finished running 'get_top_100_clusterpairs' in 0.0000 mins

# %% [markdown]
# ## Baseline 1 : <a class="anchor" id="Cluster_Similarity_vs_Model_Performance"></a>

# %%
df_result = run_bs1_train_all(X = reduced_vectors,
                          cluster_2_doc_map = doc_2_cluster_map ,
                          df = sampled_df ,
                          cluster_pairs = top100,
                          cosine_mat = cluster_pair_dist_mat,
                          thresholds = [0.5,0.7,0.9],
                          user_type="Heterogeneous")
# Out:
# Training model for cluster pair : 0
#
# Finished running 'run_model' in 0.2410 mins
#
# Training model for cluster pair : 1
#
# Finished running 'run_model' in 0.1302 mins
#
# Training model for cluster pair : 2
#
# Finished running 'run_model' in 0.5569 mins
#
# Training model for cluster pair : 3
#
# Finished running 'run_model' in 0.1036 mins
#
# Training model for cluster pair : 4
#
# Finished running 'run_model' in 0.2129 mins
#
# Training model for cluster pair : 5
#
# Finished running 'run_model' in 0.2760 mins
#
# Training model for cluster pair : 6
#
# Finished running 'run_model' in 0.1688 mins
#
# Training model for cluster pair : 7
#
# Finished running 'run_model' in 0.3006 mins
#
# Training model for cluster pair : 8
#
# Finished running 'run_model' in 0.2260 mins
#
# Training model for cluster pair : 9
#
# Finished running 'run_model' in 0.0234 mins
#
# Training model for cluster pair : 10
#
# Finished running 'run_model' in 0.1426 mins
#
# Training model for cluster pair : 11
#
# Finished running 'run_model' in 0.2225 mins
#
# Training model for cluster pair : 12
#
# Finished running 'run_model' in 0.1671 mins
#
# Training model for cluster pair : 13
#
# Finished running 'run_model' in 0.2535 mins
#
# Training model for cluster pair : 14
#
# Finished running 'run_model' in 0.1258 mins
#
# Training model for cluster pair : 15
#
# Finished running 'run_model' in 0.1709 mins
#
# Training model for cluster pair : 16
#
# Finished running 'run_model' in 0.1668 mins
#
# Training model for cluster pair : 17
#
# Finished running 'run_model' in 0.1184 mins
#
# Training model for cluster pair : 18
#
# Finished running 'run_model' in 0.1303 mins
#
# Training model for cluster pair : 19
#
# Finished running 'run_model' in 0.1470 mins
#
# Training model for cluster pair : 20
#
# Finished running 'run_model' in 0.1711 mins
#
# Training model for cluster pair : 21
#
# Finished running 'run_model' in 0.0605 mins
#
# Training model for cluster pair : 22
#
# Finished running 'run_model' in 0.2878 mins
#
# Training model for cluster pair : 23
#
# Finished running 'run_model' in 0.0575 mins
#
# Training model for cluster pair : 24
#
# Finished running 'run_model' in 0.1614 mins
#
# Training model for cluster pair : 25
#
# Finished running 'run_model' in 0.0267 mins
#
# Training model for cluster pair : 26
#
# Finished running 'run_model' in 0.2467 mins
#
# Training model for cluster pair : 27
#
# Finished running 'run_model' in 0.1069 mins
#
# Training model for cluster pair : 28
#
# Finished running 'run_model' in 0.1619 mins
#
# Training model for cluster pair : 29
#
# Finished running 'run_model' in 0.4156 mins
#
# Training model for cluster pair : 30
#
# Finished running 'run_model' in 0.1410 mins
#
# Training model for cluster pair : 31
#
# Finished running 'run_model' in 0.1372 mins
#
# Training model for cluster pair : 32
#
# Finished running 'run_model' in 0.0805 mins
#
# Training model for cluster pair : 33
#
# Finished running 'run_model' in 0.0639 mins
#
# Training model for cluster pair : 34
#
# Finished running 'run_model' in 0.3477 mins
#
# Training model for cluster pair : 35
#
# Finished running 'run_model' in 0.3773 mins
#
# Training model for cluster pair : 36
#
# Finished running 'run_model' in 0.0311 mins
#
# Training model for cluster pair : 37
#
# Finished running 'run_model' in 0.2138 mins
#
# Training model for cluster pair : 38
#
# Finished running 'run_model' in 0.1362 mins
#
# Training model for cluster pair : 39
#
# Finished running 'run_model' in 0.0718 mins
#
# Training model for cluster pair : 40
#
# Finished running 'run_model' in 0.1190 mins
#
# Training model for cluster pair : 41
#
# Finished running 'run_model' in 0.2926 mins
#
# Training model for cluster pair : 42
#
# Finished running 'run_model' in 0.3017 mins
#
# Training model for cluster pair : 43
#
# Finished running 'run_model' in 0.0684 mins
#
# Training model for cluster pair : 44
#
# Finished running 'run_model' in 0.1129 mins
#
# Training model for cluster pair : 45
#
# Finished running 'run_model' in 0.0904 mins
#
# Training model for cluster pair : 46
#
# Finished running 'run_model' in 0.1450 mins
#
# Training model for cluster pair : 47
#
# Finished running 'run_model' in 0.1186 mins
#
# Training model for cluster pair : 48
#
# Finished running 'run_model' in 0.1277 mins
#
# Training model for cluster pair : 49
#
# Finished running 'run_model' in 0.1146 mins
#
# Training model for cluster pair : 50
#
# Finished running 'run_model' in 0.2618 mins
#
# Training model for cluster pair : 51
#
# Finished running 'run_model' in 0.1418 mins
#
# Training model for cluster pair : 52
#
# Finished running 'run_model' in 0.1225 mins
#
# Training model for cluster pair : 53
#
# Finished running 'run_model' in 0.1263 mins
#
# Training model for cluster pair : 54
#
# Finished running 'run_model' in 0.1036 mins
#
# Training model for cluster pair : 55
#
# Finished running 'run_model' in 0.2222 mins
#
# Training model for cluster pair : 56
#
# Finished running 'run_model' in 0.6121 mins
#
# Training model for cluster pair : 57
#
# Finished running 'run_model' in 0.0934 mins
#
# Training model for cluster pair : 58
#
# Finished running 'run_model' in 0.6155 mins
#
# Training model for cluster pair : 59
#
# Finished running 'run_model' in 0.0945 mins
#
# Training model for cluster pair : 60
#
# Finished running 'run_model' in 0.5468 mins
#
# Training model for cluster pair : 61
#
# Finished running 'run_model' in 0.0617 mins
#
# Training model for cluster pair : 62
#
# Finished running 'run_model' in 0.2574 mins
#
# Training model for cluster pair : 63
#
# Finished running 'run_model' in 0.1516 mins
#
# Training model for cluster pair : 64
#
# Finished running 'run_model' in 0.2112 mins
#
# Training model for cluster pair : 65
#
# Finished running 'run_model' in 0.5831 mins
#
# Training model for cluster pair : 66
#
# Finished running 'run_model' in 0.0311 mins
#
# Training model for cluster pair : 67
#
# Finished running 'run_model' in 0.6133 mins
#
# Training model for cluster pair : 68
#
# Finished running 'run_model' in 0.1336 mins
#
# Training model for cluster pair : 69
#
# Finished running 'run_model' in 0.2146 mins
#
# Training model for cluster pair : 70
#
# Finished running 'run_model' in 0.1600 mins
#
# Training model for cluster pair : 71
#
# Finished running 'run_model' in 0.0740 mins
#
# Training model for cluster pair : 72
#
# Finished running 'run_model' in 0.1380 mins
#
# Training model for cluster pair : 73
#
# Finished running 'run_model' in 0.0889 mins
#
# Training model for cluster pair : 74
#
# Finished running 'run_model' in 0.0245 mins
#
# Training model for cluster pair : 75
#
# Finished running 'run_model' in 0.2063 mins
#
# Training model for cluster pair : 76
#
# Finished running 'run_model' in 0.5858 mins
#
# Training model for cluster pair : 77
#
# Finished running 'run_model' in 0.0679 mins
#
# Training model for cluster pair : 78
#
# Finished running 'run_model' in 0.0527 mins
#
# Training model for cluster pair : 79
#
# Finished running 'run_model' in 0.2303 mins
#
# Training model for cluster pair : 80
#
# Finished running 'run_model' in 0.1150 mins
#
# Training model for cluster pair : 81
#
# Finished running 'run_model' in 0.1391 mins
#
# Training model for cluster pair : 82
#
# Finished running 'run_model' in 0.0584 mins
#
# Training model for cluster pair : 83
#
# Finished running 'run_model' in 0.1482 mins
#
# Training model for cluster pair : 84
#
# Finished running 'run_model' in 0.2701 mins
#
# Training model for cluster pair : 85
#
# Finished running 'run_model' in 0.1146 mins
#
# Training model for cluster pair : 86
#
# Finished running 'run_model' in 0.0558 mins
#
# Training model for cluster pair : 87
#
# Finished running 'run_model' in 0.2363 mins
#
# Training model for cluster pair : 88
#
# Finished running 'run_model' in 0.0555 mins
#
# Training model for cluster pair : 89
#
# Finished running 'run_model' in 0.1484 mins
#
# Training model for cluster pair : 90
#
# Finished running 'run_model' in 0.1604 mins
#
# Training model for cluster pair : 91
#
# Finished running 'run_model' in 0.2488 mins
#
# Training model for cluster pair : 92
#
# Finished running 'run_model' in 0.1930 mins
#
# Training model for cluster pair : 93
#
# Finished running 'run_model' in 0.1609 mins
#
# Training model for cluster pair : 94
#
# Finished running 'run_model' in 0.0251 mins
#
# Training model for cluster pair : 95
#
# Finished running 'run_model' in 0.0814 mins
#
# Training model for cluster pair : 96
#
# Finished running 'run_model' in 0.4149 mins
#
# Training model for cluster pair : 97
#
# Finished running 'run_model' in 0.2064 mins
#
# Training model for cluster pair : 98
#
# Finished running 'run_model' in 0.1497 mins
#
# Training model for cluster pair : 99
#
# Finished running 'run_model' in 0.0955 mins
#
#
# Finished running 'run_bs1_train_all' in 18.6111 mins

# %%
df_result_homog = run_bs1_train_all(X = reduced_vectors,
                          cluster_2_doc_map = doc_2_cluster_map ,
                          df = sampled_df ,
                          cluster_pairs = top100,
                          cosine_mat = cluster_pair_dist_mat,
                          thresholds = [0.5,0.7,0.9],
                          user_type="Homogeneous")
# Out:
# Training model for cluster pair : 0
#
# Finished running 'run_model' in 0.2306 mins
#
# Training model for cluster pair : 1
#
# Finished running 'run_model' in 0.1696 mins
#
# Training model for cluster pair : 2
#
# Finished running 'run_model' in 0.5798 mins
#
# Training model for cluster pair : 3
#
# Finished running 'run_model' in 0.0926 mins
#
# Training model for cluster pair : 4
#
# Finished running 'run_model' in 0.2353 mins
#
# Training model for cluster pair : 5
#
# Finished running 'run_model' in 0.2571 mins
#
# Training model for cluster pair : 6
#
# Finished running 'run_model' in 0.1632 mins
#
# Training model for cluster pair : 7
#
# Finished running 'run_model' in 0.2719 mins
#
# Training model for cluster pair : 8
#
# Finished running 'run_model' in 0.2314 mins
#
# Training model for cluster pair : 9
#
# Finished running 'run_model' in 0.0282 mins
#
# Training model for cluster pair : 10
#
# Finished running 'run_model' in 0.1818 mins
#
# Training model for cluster pair : 11
#
# Finished running 'run_model' in 0.2361 mins
#
# Training model for cluster pair : 12
#
# Finished running 'run_model' in 0.1633 mins
#
# Training model for cluster pair : 13
#
# Finished running 'run_model' in 0.2294 mins
#
# Training model for cluster pair : 14
#
# Finished running 'run_model' in 0.1247 mins
#
# Training model for cluster pair : 15
#
# Finished running 'run_model' in 0.1935 mins
#
# Training model for cluster pair : 16
#
# Finished running 'run_model' in 0.1659 mins
#
# Training model for cluster pair : 17
#
# Finished running 'run_model' in 0.1124 mins
#
# Training model for cluster pair : 18
#
# Finished running 'run_model' in 0.1472 mins
#
# Training model for cluster pair : 19
#
# Finished running 'run_model' in 0.1436 mins
#
# Training model for cluster pair : 20
#
# Finished running 'run_model' in 0.2578 mins
#
# Training model for cluster pair : 21
#
# Finished running 'run_model' in 0.0573 mins
#
# Training model for cluster pair : 22
#
# Finished running 'run_model' in 0.2735 mins
#
# Training model for cluster pair : 23
#
# Finished running 'run_model' in 0.0697 mins
#
# Training model for cluster pair : 24
#
# Finished running 'run_model' in 0.1726 mins
#
# Training model for cluster pair : 25
#
# Finished running 'run_model' in 0.0312 mins
#
# Training model for cluster pair : 26
#
# Finished running 'run_model' in 0.2625 mins
#
# Training model for cluster pair : 27
#
# Finished running 'run_model' in 0.0900 mins
#
# Training model for cluster pair : 28
#
# Finished running 'run_model' in 0.1666 mins
#
# Training model for cluster pair : 29
#
# Finished running 'run_model' in 0.3905 mins
#
# Training model for cluster pair : 30
#
# Finished running 'run_model' in 0.1706 mins
#
# Training model for cluster pair : 31
#
# Finished running 'run_model' in 0.1401 mins
#
# Training model for cluster pair : 32
#
# Finished running 'run_model' in 0.0851 mins
#
# Training model for cluster pair : 33
#
# Finished running 'run_model' in 0.0600 mins
#
# Training model for cluster pair : 34
#
# Finished running 'run_model' in 0.3569 mins
#
# Training model for cluster pair : 35
#
# Finished running 'run_model' in 0.3729 mins
#
# Training model for cluster pair : 36
#
# Finished running 'run_model' in 0.0279 mins
#
# Training model for cluster pair : 37
#
# Finished running 'run_model' in 0.2327 mins
#
# Training model for cluster pair : 38
#
# Finished running 'run_model' in 0.1359 mins
#
# Training model for cluster pair : 39
#
# Finished running 'run_model' in 0.0698 mins
#
# Training model for cluster pair : 40
#
# Finished running 'run_model' in 0.0917 mins
#
# Training model for cluster pair : 41
#
# Finished running 'run_model' in 0.2554 mins
#
# Training model for cluster pair : 42
#
# Finished running 'run_model' in 0.2717 mins
#
# Training model for cluster pair : 43
#
# Finished running 'run_model' in 0.0664 mins
#
# Training model for cluster pair : 44
#
# Finished running 'run_model' in 0.1176 mins
#
# Training model for cluster pair : 45
#
# Finished running 'run_model' in 0.1119 mins
#
# Training model for cluster pair : 46
#
# Finished running 'run_model' in 0.1210 mins
#
# Training model for cluster pair : 47
#
# Finished running 'run_model' in 0.1230 mins
#
# Training model for cluster pair : 48
#
# Finished running 'run_model' in 0.1319 mins
#
# Training model for cluster pair : 49
#
# Finished running 'run_model' in 0.1262 mins
#
# Training model for cluster pair : 50
#
# Finished running 'run_model' in 0.2661 mins
#
# Training model for cluster pair : 51
#
# Finished running 'run_model' in 0.1410 mins
#
# Training model for cluster pair : 52
#
# Finished running 'run_model' in 0.1257 mins
#
# Training model for cluster pair : 53
#
# Finished running 'run_model' in 0.1215 mins
#
# Training model for cluster pair : 54
#
# Finished running 'run_model' in 0.1270 mins
#
# Training model for cluster pair : 55
#
# Finished running 'run_model' in 0.1797 mins
#
# Training model for cluster pair : 56
#
# Finished running 'run_model' in 0.5662 mins
#
# Training model for cluster pair : 57
#
# Finished running 'run_model' in 0.1029 mins
#
# Training model for cluster pair : 58
#
# Finished running 'run_model' in 0.5769 mins
#
# Training model for cluster pair : 59
#
# Finished running 'run_model' in 0.0873 mins
#
# Training model for cluster pair : 60
#
# Finished running 'run_model' in 0.5827 mins
#
# Training model for cluster pair : 61
#
# Finished running 'run_model' in 0.0590 mins
#
# Training model for cluster pair : 62
#
# Finished running 'run_model' in 0.2570 mins
#
# Training model for cluster pair : 63
#
# Finished running 'run_model' in 0.1688 mins
#
# Training model for cluster pair : 64
#
# Finished running 'run_model' in 0.2130 mins
#
# Training model for cluster pair : 65
#
# Finished running 'run_model' in 0.5583 mins
#
# Training model for cluster pair : 66
#
# Finished running 'run_model' in 0.0256 mins
#
# Training model for cluster pair : 67
#
# Finished running 'run_model' in 0.6480 mins
#
# Training model for cluster pair : 68
#
# Finished running 'run_model' in 0.1288 mins
#
# Training model for cluster pair : 69
#
# Finished running 'run_model' in 0.2120 mins
#
# Training model for cluster pair : 70
#
# Finished running 'run_model' in 0.1802 mins
#
# Training model for cluster pair : 71
#
# Finished running 'run_model' in 0.0663 mins
#
# Training model for cluster pair : 72
#
# Finished running 'run_model' in 0.1736 mins
#
# Training model for cluster pair : 73
#
# Finished running 'run_model' in 0.1272 mins
#
# Training model for cluster pair : 74
#
# Finished running 'run_model' in 0.0292 mins
#
# Training model for cluster pair : 75
#
# Finished running 'run_model' in 0.2115 mins
#
# Training model for cluster pair : 76
#
# Finished running 'run_model' in 0.5913 mins
#
# Training model for cluster pair : 77
#
# Finished running 'run_model' in 0.0658 mins
#
# Training model for cluster pair : 78
#
# Finished running 'run_model' in 0.0555 mins
#
# Training model for cluster pair : 79
#
# Finished running 'run_model' in 0.1821 mins
#
# Training model for cluster pair : 80
#
# Finished running 'run_model' in 0.1114 mins
#
# Training model for cluster pair : 81
#
# Finished running 'run_model' in 0.1188 mins
#
# Training model for cluster pair : 82
#
# Finished running 'run_model' in 0.0503 mins
#
# Training model for cluster pair : 83
#
# Finished running 'run_model' in 0.1325 mins
#
# Training model for cluster pair : 84
#
# Finished running 'run_model' in 0.2384 mins
#
# Training model for cluster pair : 85
#
# Finished running 'run_model' in 0.0777 mins
#
# Training model for cluster pair : 86
#
# Finished running 'run_model' in 0.0445 mins
#
# Training model for cluster pair : 87
#
# Finished running 'run_model' in 0.1689 mins
#
# Training model for cluster pair : 88
#
# Finished running 'run_model' in 0.0460 mins
#
# Training model for cluster pair : 89
#
# Finished running 'run_model' in 0.1189 mins
#
# Training model for cluster pair : 90
#
# Finished running 'run_model' in 0.1304 mins
#
# Training model for cluster pair : 91
#
# Finished running 'run_model' in 0.2106 mins
#
# Training model for cluster pair : 92
#
# Finished running 'run_model' in 0.1496 mins
#
# Training model for cluster pair : 93
#
# Finished running 'run_model' in 0.1595 mins
#
# Training model for cluster pair : 94
#
# Finished running 'run_model' in 0.0194 mins
#
# Training model for cluster pair : 95
#
# Finished running 'run_model' in 0.0610 mins
#
# Training model for cluster pair : 96
#
# Finished running 'run_model' in 0.3375 mins
#
# Training model for cluster pair : 97
#
# Finished running 'run_model' in 0.1841 mins
#
# Training model for cluster pair : 98
#
# Finished running 'run_model' in 0.1284 mins
#
# Training model for cluster pair : 99
#
# Finished running 'run_model' in 0.0882 mins
#
#
# Finished running 'run_bs1_train_all' in 18.2293 mins

# %%
for threshold in [0.5,0.7,0.9]:
    bsl1_sim_vs_score_all_users(df_results_hetero=df_result,
                                df_results_homo=df_result_homog,
                                threshold=threshold)
# Out:
# Finished running 'bsl1_sim_vs_score_all_users' in 0.0232 mins
# Finished running 'bsl1_sim_vs_score_all_users' in 0.0221 mins
# Finished running 'bsl1_sim_vs_score_all_users' in 0.0219 mins

# %% [markdown]
# <!-- ## Online Learning Setting - Active Learning Setting (Performance Measured on Held Out Validation Dataset) -->

# %% [markdown]
# ## Baseline 2 : <a class="anchor" id="Online_Setting_Performance"></a>

# %%
hetero_scores,df_res_map_hetero = run_bs2_train_all(X=reduced_vectors,
                                   cluster_2_doc_map=doc_2_cluster_map,
                                   df=sampled_df,
                                   cluster_pairs=top100,
                                   cosine_mat=cluster_pair_dist_mat,
                                   user_type="Heterogeneous")
# Out:
# Training model for cluster pair : (137, 228)
# Training model for cluster pair : (19, 87)
# Training model for cluster pair : (66, 87)
# Training model for cluster pair : (87, 228)
# Training model for cluster pair : (209, 514)
# Training model for cluster pair : (12, 40)
# Training model for cluster pair : (19, 567)
# Training model for cluster pair : (189, 778)
# Training model for cluster pair : (196, 280)
# Training model for cluster pair : (40, 87)
# Training model for cluster pair : (53, 323)
# Training model for cluster pair : (137, 439)
# Training model for cluster pair : (19, 40)
# Training model for cluster pair : (240, 514)
# Training model for cluster pair : (77, 567)
# Training model for cluster pair : (145, 769)
# Training model for cluster pair : (53, 422)
# Training model for cluster pair : (87, 137)
# Training model for cluster pair : (123, 209)
# Training model for cluster pair : (19, 66)
# Training model for cluster pair : (32, 145)
# Training model for cluster pair : (208, 626)
# Training model for cluster pair : (12, 77)
# Training model for cluster pair : (133, 323)
# Training model for cluster pair : (14, 145)
# Training model for cluster pair : (40, 228)
# Training model for cluster pair : (12, 567)
# Training model for cluster pair : (56, 209)
# Training model for cluster pair : (19, 626)
# Training model for cluster pair : (275, 626)
# Training model for cluster pair : (19, 208)
# Training model for cluster pair : (77, 439)
# Training model for cluster pair : (497, 514)
# Training model for cluster pair : (778, 872)
# Training model for cluster pair : (422, 514)
# Training model for cluster pair : (228, 422)
# Training model for cluster pair : (40, 66)
# Training model for cluster pair : (32, 769)
# Training model for cluster pair : (123, 514)
# Training model for cluster pair : (133, 228)
# Training model for cluster pair : (87, 275)
# Training model for cluster pair : (12, 19)
# Training model for cluster pair : (12, 66)
# Training model for cluster pair : (133, 275)
# Training model for cluster pair : (87, 626)
# Training model for cluster pair : (56, 240)
# Training model for cluster pair : (77, 137)
# Training model for cluster pair : (439, 872)
# Training model for cluster pair : (56, 514)
# Training model for cluster pair : (56, 145)
# Training model for cluster pair : (12, 87)
# Training model for cluster pair : (19, 189)
# Training model for cluster pair : (67, 196)
# Training model for cluster pair : (77, 280)
# Training model for cluster pair : (56, 769)
# Training model for cluster pair : (32, 397)
# Training model for cluster pair : (66, 567)
# Training model for cluster pair : (87, 567)
# Training model for cluster pair : (66, 208)
# Training model for cluster pair : (87, 133)
# Training model for cluster pair : (66, 626)
# Training model for cluster pair : (208, 323)
# Training model for cluster pair : (12, 211)
# Training model for cluster pair : (19, 228)
# Training model for cluster pair : (209, 342)
# Training model for cluster pair : (66, 228)
# Training model for cluster pair : (40, 567)
# Training model for cluster pair : (66, 275)
# Training model for cluster pair : (67, 275)
# Training model for cluster pair : (137, 189)
# Training model for cluster pair : (19, 137)
# Training model for cluster pair : (133, 208)
# Training model for cluster pair : (19, 323)
# Training model for cluster pair : (87, 208)
# Training model for cluster pair : (40, 137)
# Training model for cluster pair : (32, 209)
# Training model for cluster pair : (66, 422)
# Training model for cluster pair : (133, 422)
# Training model for cluster pair : (208, 292)
# Training model for cluster pair : (209, 240)
# Training model for cluster pair : (323, 422)
# Training model for cluster pair : (19, 292)
# Training model for cluster pair : (342, 514)
# Training model for cluster pair : (19, 133)
# Training model for cluster pair : (12, 137)
# Training model for cluster pair : (87, 422)
# Training model for cluster pair : (342, 769)
# Training model for cluster pair : (137, 567)
# Training model for cluster pair : (208, 275)
# Training model for cluster pair : (19, 280)
# Training model for cluster pair : (53, 66)
# Training model for cluster pair : (12, 280)
# Training model for cluster pair : (32, 514)
# Training model for cluster pair : (19, 275)
# Training model for cluster pair : (40, 280)
# Training model for cluster pair : (280, 439)
# Training model for cluster pair : (228, 275)
# Training model for cluster pair : (209, 323)
# Training model for cluster pair : (53, 123)
# Training model for cluster pair : (87, 323)
#
# Finished running 'run_bs2_train_all' in 5.9926 mins

# %%
homo_scores, df_res_map_homo =  run_bs2_train_all(X=reduced_vectors,
                                   cluster_2_doc_map=doc_2_cluster_map,
                                   df=sampled_df,
                                   cluster_pairs=top100,
                                   cosine_mat=cluster_pair_dist_mat,
                                   user_type="Homogeneous")
# Out:
# Training model for cluster pair : (137, 228)
# Training model for cluster pair : (19, 87)
# Training model for cluster pair : (66, 87)
# Training model for cluster pair : (87, 228)
# Training model for cluster pair : (209, 514)
# Training model for cluster pair : (12, 40)
# Training model for cluster pair : (19, 567)
# Training model for cluster pair : (189, 778)
# Training model for cluster pair : (196, 280)
# Training model for cluster pair : (40, 87)
# Training model for cluster pair : (53, 323)
# Training model for cluster pair : (137, 439)
# Training model for cluster pair : (19, 40)
# Training model for cluster pair : (240, 514)
# Training model for cluster pair : (77, 567)
# Training model for cluster pair : (145, 769)
# Training model for cluster pair : (53, 422)
# Training model for cluster pair : (87, 137)
# Training model for cluster pair : (123, 209)
# Training model for cluster pair : (19, 66)
# Training model for cluster pair : (32, 145)
# Training model for cluster pair : (208, 626)
# Training model for cluster pair : (12, 77)
# Training model for cluster pair : (133, 323)
# Training model for cluster pair : (14, 145)
# Training model for cluster pair : (40, 228)
# Training model for cluster pair : (12, 567)
# Training model for cluster pair : (56, 209)
# Training model for cluster pair : (19, 626)
# Training model for cluster pair : (275, 626)
# Training model for cluster pair : (19, 208)
# Training model for cluster pair : (77, 439)
# Training model for cluster pair : (497, 514)
# Training model for cluster pair : (778, 872)
# Training model for cluster pair : (422, 514)
# Training model for cluster pair : (228, 422)
# Training model for cluster pair : (40, 66)
# Training model for cluster pair : (32, 769)
# Training model for cluster pair : (123, 514)
# Training model for cluster pair : (133, 228)
# Training model for cluster pair : (87, 275)
# Training model for cluster pair : (12, 19)
# Training model for cluster pair : (12, 66)
# Training model for cluster pair : (133, 275)
# Training model for cluster pair : (87, 626)
# Training model for cluster pair : (56, 240)
# Training model for cluster pair : (77, 137)
# Training model for cluster pair : (439, 872)
# Training model for cluster pair : (56, 514)
# Training model for cluster pair : (56, 145)
# Training model for cluster pair : (12, 87)
# Training model for cluster pair : (19, 189)
# Training model for cluster pair : (67, 196)
# Training model for cluster pair : (77, 280)
# Training model for cluster pair : (56, 769)
# Training model for cluster pair : (32, 397)
# Training model for cluster pair : (66, 567)
# Training model for cluster pair : (87, 567)
# Training model for cluster pair : (66, 208)
# Training model for cluster pair : (87, 133)
# Training model for cluster pair : (66, 626)
# Training model for cluster pair : (208, 323)
# Training model for cluster pair : (12, 211)
# Training model for cluster pair : (19, 228)
# Training model for cluster pair : (209, 342)
# Training model for cluster pair : (66, 228)
# Training model for cluster pair : (40, 567)
# Training model for cluster pair : (66, 275)
# Training model for cluster pair : (67, 275)
# Training model for cluster pair : (137, 189)
# Training model for cluster pair : (19, 137)
# Training model for cluster pair : (133, 208)
# Training model for cluster pair : (19, 323)
# Training model for cluster pair : (87, 208)
# Training model for cluster pair : (40, 137)
# Training model for cluster pair : (32, 209)
# Training model for cluster pair : (66, 422)
# Training model for cluster pair : (133, 422)
# Training model for cluster pair : (208, 292)
# Training model for cluster pair : (209, 240)
# Training model for cluster pair : (323, 422)
# Training model for cluster pair : (19, 292)
# Training model for cluster pair : (342, 514)
# Training model for cluster pair : (19, 133)
# Training model for cluster pair : (12, 137)
# Training model for cluster pair : (87, 422)
# Training model for cluster pair : (342, 769)
# Training model for cluster pair : (137, 567)
# Training model for cluster pair : (208, 275)
# Training model for cluster pair : (19, 280)
# Training model for cluster pair : (53, 66)
# Training model for cluster pair : (12, 280)
# Training model for cluster pair : (32, 514)
# Training model for cluster pair : (19, 275)
# Training model for cluster pair : (40, 280)
# Training model for cluster pair : (280, 439)
# Training model for cluster pair : (228, 275)
# Training model for cluster pair : (209, 323)
# Training model for cluster pair : (53, 123)
# Training model for cluster pair : (87, 323)
#
# Finished running 'run_bs2_train_all' in 5.7801 mins

# %%
plot_online_learning_cumulative(homo_scores,hetero_scores,active=False)
# Out:
# Finished running 'combine_scores_cumu_online_setting' in 0.0001 mins
#
#
# Finished running 'combine_scores_cumu_online_setting' in 0.0001 mins
# Finished running 'plot_online_setting_per_clusterpair' in 0.0191 mins
#
#
# Finished running 'plot_online_learning_cumulative' in 0.0192 mins

# %%
plot_all_cp_online(homo_scores,user_type="Homogeneous",metric="precision")
# Out:
# Finished running 'plot_all_cp_online' in 0.0629 mins

# %%
plot_all_cp_online(hetero_scores,user_type="Heterogeneous",metric="precision")
# Out:
# Finished running 'plot_all_cp_online' in 0.0623 mins

# %%
avg_presc_homo = calculate_avg_precision(homo_scores,mode="single")

# %%
np.mean(avg_presc_homo)
# Out:
# 0.6597649976149833

# %%
avg_presc_hetero = calculate_avg_precision(hetero_scores,mode="single")

# %%
np.mean(avg_presc_hetero)
# Out:
# 0.3422261441923841

# %% [markdown]
# ## Baseline 3 :  <a class="anchor" id="Single_Cluster_Online_Setting_Performance"></a>

# %%
hetero_scores = run_bs3_train_all(X=reduced_vectors,
                                   cluster_2_doc_map=doc_2_cluster_map,
                                   df=sampled_df,
                                   cluster_pairs=top100,
                                   cosine_mat=cluster_pair_dist_mat,
                                   user_type="Heterogeneous")
# Out:
# Training model for cluster pair : 0
# Training model for cluster pair : 1
# Training model for cluster pair : 2
# Training model for cluster pair : 3
# Training model for cluster pair : 4
# Training model for cluster pair : 5
# Training model for cluster pair : 6
# Training model for cluster pair : 7
# Training model for cluster pair : 8
# Training model for cluster pair : 9
# Training model for cluster pair : 10
# Training model for cluster pair : 11
# Training model for cluster pair : 12
# Training model for cluster pair : 13
# Training model for cluster pair : 14
# Training model for cluster pair : 15
# Training model for cluster pair : 16
# Training model for cluster pair : 17
# Training model for cluster pair : 18
# Training model for cluster pair : 19
# Training model for cluster pair : 20
# Training model for cluster pair : 21
# Training model for cluster pair : 22
# Training model for cluster pair : 23
# Training model for cluster pair : 24
# Training model for cluster pair : 25
# Training model for cluster pair : 26
# Training model for cluster pair : 27
# Training model for cluster pair : 28
# Training model for cluster pair : 29
# Training model for cluster pair : 30
# Training model for cluster pair : 31
# Training model for cluster pair : 32
# Training model for cluster pair : 33
# Training model for cluster pair : 34

# %%
homo_scores =  run_bs3_train_all(X=reduced_vectors,
                                   cluster_2_doc_map=doc_2_cluster_map,
                                   df=sampled_df,
                                   cluster_pairs=top100,
                                   cosine_mat=cluster_pair_dist_mat,
                                   user_type="Homogeneous")

# %%
plot_single_cluster_cumulative(homo_scores,hetero_scores)

# %%
plot_all_cp_singlecluster(homo_scores)

# %%
avg_presc_homo = calculate_avg_precision(homo_scores,mode="single")

# %%
np.mean(avg_presc_homo)

# %% [markdown]
# ## Baseline 4: <a class="anchor" id="Regularization_vs_Online_Setting_Performance"></a>

# %%
hetero_scores = run_bs4_train_all(X=reduced_vectors,
                                   cluster_2_doc_map=doc_2_cluster_map,
                                   df=sampled_df,
                                   cluster_pairs=top100,
                                   cosine_mat=cluster_pair_dist_mat,
                                 user_type="Heterogeneous",
                                 reg_constants=[0.0001,0.001,0.01,0.1,0.0,1.0,10.0,20.0,50.0,100.0])

# %%
homo_scores = run_bs4_train_all(X=reduced_vectors,
                                   cluster_2_doc_map=doc_2_cluster_map,
                                   df=sampled_df,
                                   cluster_pairs=top100,
                                   cosine_mat=cluster_pair_dist_mat,
                                 user_type="Homogeneous",
                                 reg_constants=[0.0001,0.001,0.01,0.1,0.0,1.0,10.0,20.0,50.0,100.0])

# %%
plot_regularization_vs_metrics_at_k_cumu(homo_scores,
                                         regularization_constants=[0.0001,0.001,0.01,0.1,0.0,1.0,10.0,20.0,50.0,100.0],
                                         user_type="Homogeneous")

# %%
plot_regularization_vs_metrics_at_k_cumu(hetero_scores,
                                         regularization_constants=[0.0001,0.001,0.01,0.1,0.0,1.0,10.0,20.0,50.0,100.0])

# %%
homo_param_res = calculate_avg_precision_param_variation(homo_scores,
                                                         params=[0.0001,0.001,0.01,0.1,0.0,1.0,10.0,20.0,50.0,100.0])

# %%
calculate_map_param_variation(homo_param_res)

# %%
hetero_param_res = calculate_avg_precision_param_variation(hetero_scores,
                                                         params=[0.0001,0.001,0.01,0.1,0.0,1.0,10.0,20.0,50.0,100.0])

# %%
calculate_map_param_variation(hetero_param_res)

# %% [markdown]
# ## Baseline 5 : <a class="anchor" id="Learning_Rate_vs_Online_Setting_Performance"></a>

# %%
hetero_scores,df_het_res_100,df_het_res_500 = run_bs5_train_all(X=reduced_vectors,sample_df=sampled_df,
                                   cluster_2_doc_map=doc_2_cluster_map,
                                   df=sampled_df,
                                   cluster_pairs=top100,
                                   cosine_mat=cluster_pair_dist_mat,
                                 user_type="Heterogeneous",
                                 lr=[0.001,0.01,0.1,1.0,10,15,20,50,100,500])

# %%
homo_scores,df_hom_res_100,df_hom_res_500 = run_bs5_train_all(X=reduced_vectors,sample_df=sampled_df,
                                   cluster_2_doc_map=doc_2_cluster_map,
                                   df=sampled_df,
                                   cluster_pairs=top100,
                                   cosine_mat=cluster_pair_dist_mat,
                                 user_type="Homogeneous",
                                 lr=[0.001,0.01,0.1,1.0,10,15,20,50,100,500])

# %%
plot_lr_vs_metrics_at_k_cumu(homo_scores,
                             lr=[0.001,0.01,0.1,1.0,10,15,20,50,100,500],
                             user_type="Homogeneous")

# %%
plot_lr_vs_metrics_at_k_cumu(hetero_scores,
                             lr=[0.001,0.01,0.1,1.0,10,15,20,50,100,500])

# %%
homo_param_res = calculate_avg_precision_param_variation(homo_scores,
                                                         params=[0.001,0.01,0.1,1.0,10,15,20,50,100,500])

# %%
calculate_map_param_variation(homo_param_res)

# %%
hetero_param_res = calculate_avg_precision_param_variation(hetero_scores,
                                                         params=[0.001,0.01,0.1,1.0,10,15,20,50,100,500])

# %%
calculate_map_param_variation(hetero_param_res)

# %% [markdown]
# ## Baseline 6: <a class="anchor" id="Online_Setting_Mixed_Data_Performance"></a>

# %%
hetero_scores = run_bs6_train_all(X=reduced_vectors,
                                   cluster_2_doc_map=doc_2_cluster_map,
                                   df=sampled_df,
                                   cluster_pairs=top100,
                                   cosine_mat=cluster_pair_dist_mat,
                                 user_type="Heterogeneous")

# %%
homo_scores = run_bs6_train_all(X=reduced_vectors,
                                   cluster_2_doc_map=doc_2_cluster_map,
                                   df=sampled_df,
                                   cluster_pairs=top100,
                                   cosine_mat=cluster_pair_dist_mat,
                                 user_type="Homogeneous")

# %%
# homo_scores.keys()

# %%
# plot_mixed_data_performance_per_cluster(homo_scores[(585, 712)],hetero_scores[(585, 712)])

# %%
plot_mixed_cluster_cumulative_per_cluster(homo_scores,hetero_scores)

# %%
plot_mixed_data_all_cp_perf(scores_cp=homo_scores,user_type="Homogeneous",metric="precision")

# %%
plot_mixed_data_all_cp_perf(scores_cp=hetero_scores,user_type="Heterogeneous",metric="precision")

# %%
avg_presc_homo,avg_presc_homo_c1, avg_presc_homo_c2 = calculate_avg_precision(homo_scores,mode="mixed")

# %%
np.mean(avg_presc_homo)

# %%
np.mean(avg_presc_homo_c1)

# %%
np.mean(avg_presc_homo_c2)

# %%
avg_presc_hetero,avg_presc_hetero_c1, avg_presc_hetero_c2 = calculate_avg_precision(hetero_scores,mode="mixed")

# %%
np.mean(avg_presc_hetero)

# %%
np.mean(avg_presc_hetero_c1)

# %%
np.mean(avg_presc_hetero_c2)

# %% [markdown]
# ## Baseline 7 : <a class="anchor" id="Learning_Rate_vs_Online_Setting_Mixed_Data_Performance"></a>

# %%
hetero_scores = run_bs7_train_all(X=reduced_vectors,
                                   cluster_2_doc_map=doc_2_cluster_map,
                                   df=sampled_df,
                                   cluster_pairs=top100,
                                   cosine_mat=cluster_pair_dist_mat,
                                 user_type="Heterogeneous",
                                 lr=[0.001,0.01,0.1,1.0,10,15,20,50,100,500])

# %%
homo_scores = run_bs7_train_all(X=reduced_vectors,
                                   cluster_2_doc_map=doc_2_cluster_map,
                                   df=sampled_df,
                                   cluster_pairs=top100,
                                   cosine_mat=cluster_pair_dist_mat,
                                 user_type="Homogeneous",
                                 lr=[0.001,0.01,0.1,1.0,10,15,20,50,100,500])

# %%
# plot_lr_vs_metrics_at_k_mixed(homo_scores[(585, 712)],
#                                     lr=[0.001,0.01,0.1,1.0,10,15,20,50,100,500],user_type="Homogeneous")

# %%
# plot_lr_vs_metrics_at_k_mixed(hetero_scores[(585, 712)],
#                                     lr=[0.001,0.01,0.1,1.0,10,15,20,50,100,500])

# %%
plot_lr_vs_metrics_at_k_cumu(homo_scores,
                             lr=[0.001,0.01,0.1,1.0,10,15,20,50,100,500],
                             user_type="Homogeneous",mixed_data=True)

# %%
plot_lr_vs_metrics_at_k_cumu(hetero_scores,
                             lr=[0.001,0.01,0.1,1.0,10,15,20,50,100,500],mixed_data=True)

# %%
#  plot_mixed_data_all_cp_precis_lr(scores_=homo_scores,
#                              lr=[0.001,0.01,0.1,1.0,10,15,20,50,100,500],
#                              user_type="Homogeneous",metric="precision")

# %%
#  plot_mixed_data_all_cp_precis_lr(scores_=hetero_scores,
#                              lr=[0.001,0.01,0.1,1.0,10,15,20,50,100,500],
#                              user_type="Heterogeneous",metric="precision")

# %%
homo_param_res = calculate_avg_precision_param_variation(homo_scores,
                                                         params=[0.001,0.01,0.1,1.0,10,15,20,50,100,500],mode="mixed")

# %%
calculate_map_param_variation(homo_param_res,mode="mixed")

# %%
hetero_param_res = calculate_avg_precision_param_variation(hetero_scores,
                                                         params=[0.001,0.01,0.1,1.0,10,15,20,50,100,500],mode="mixed")

# %%
calculate_map_param_variation(hetero_param_res,mode="mixed")
